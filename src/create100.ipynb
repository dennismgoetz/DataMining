# %%
from routemining import createfiles

createfiles("../data/actual100.json", "../data/standard100.json", "../results/recStandard100.json", 1, prints=True)

createfiles("../data/actual100.json", "../data/standard100.json", "../results/driver100.json",2, prints=True)

createfiles("../data/actual100.json", "../data/standard100.json", "../results/perfectRoute100.json", 3,  prints=True, printsalot=True)
# Out:
# Loading data
# Finding dimension sizes
# Creating points
# Clustering points
# Rebuild dataset
# Finding frequent routes
# Finding info for driver:  A
# loading data
# mapping partition borders
# converting routes into minhash signatures
# comparing using jaccard similarity
# Finding info for driver:  B
# loading data
# mapping partition borders
# converting routes into minhash signatures
# comparing using jaccard similarity
# Finding info for driver:  C
# loading data
# mapping partition borders
# converting routes into minhash signatures
# comparing using jaccard similarity
# Finding info for driver:  D
# loading data
# mapping partition borders
# converting routes into minhash signatures
# comparing using jaccard similarity
# Finding info for driver:  E
# loading data
# mapping partition borders
# converting routes into minhash signatures
# comparing using jaccard similarity
# Finding info for driver:  F
# loading data
# mapping partition borders
# ...

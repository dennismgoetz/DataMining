# %%
dataset= (('a1', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a4', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a5', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a6', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a7', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a8', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a9', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a10', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a11', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a12', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a13', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a14', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a15', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a16', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a17', 'B', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a18', 'B', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a19', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a20', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a21', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a22', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a23', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a24', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a25', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a26', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a27', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a28', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a29', 'J', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Milano-0', 'Milano-Trento-0', 'Trento-Milano-0')), ('a30', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a31', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a32', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a33', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a34', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a35', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a36', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a37', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a38', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a39', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a40', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a41', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a42', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a43', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a44', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a45', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a46', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a47', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a48', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a49', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a50', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a51', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a52', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a53', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a54', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a55', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a56', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a57', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a58', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a59', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a60', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a61', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a62', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0', 'Trento-Monza-0')), ('a63', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a64', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a65', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-0')), ('a66', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a67', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a68', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a69', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a70', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a71', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a72', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a73', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a74', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a75', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a76', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a77', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a78', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a79', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a80', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a81', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a82', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a83', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a84', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a85', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a86', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a87', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a88', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Rome-0', 'Rome-Trento-1', 'Trento-Udine-0')), ('a89', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a90', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a91', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a92', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a93', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a94', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a95', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a96', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a97', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a98', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a99', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Lecce-0', 'Lecce-Trento-1')), ('a100', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a101', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a102', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a103', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a104', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a105', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a106', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Siena-0')), ('a107', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a108', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a109', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a110', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a111', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a112', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a113', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a114', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a115', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a116', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a117', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a118', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a119', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a120', 'J', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0')), ('a121', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a122', 'B', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a123', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a124', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a125', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a126', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a127', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-1', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a128', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a129', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a130', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a131', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Torino-0', 'Torino-Pisa-0', 'Pisa-Genova-0', 'Genova-Trento-0')), ('a132', 'B', 's1', ('Genova-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Monza-0', 'Monza-Padua-0')), ('a133', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a134', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a135', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a136', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a137', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a138', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a139', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a140', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a141', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a142', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Firenze-0', 'Firenze-Trento-0')), ('a143', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a144', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a145', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a146', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a147', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a148', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a149', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5', 'Trento-Rome-0')), ('a150', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a151', 'J', 's1', ('Napoli-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a152', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a153', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a154', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a155', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a156', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a157', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a158', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a159', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a160', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0')), ('a161', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a162', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a163', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a164', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a165', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Lecce-0', 'Lecce-Bolzano-0')), ('a166', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a167', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a168', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a169', 'J', 's1', ('Modena-Monza-0', 'Monza-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Firenze-0', 'Firenze-Trento-0')), ('a170', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a171', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a172', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a173', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a174', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a175', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a176', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a177', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a178', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a179', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a180', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a181', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a182', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a183', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a184', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a185', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a186', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a187', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a188', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a189', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Udine-0', 'Udine-Trento-0', 'Trento-Genova-0')), ('a190', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a191', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a192', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-2')), ('a193', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a194', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Bologna-0', 'Bologna-Rome-0', 'Rome-Trento-0', 'Trento-Torino-0')), ('a195', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a196', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a197', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a198', 'J', 's1', ('Udine-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a199', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a200', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a201', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a202', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Bologna-0', 'Bologna-Trento-0', 'Trento-Bolzano-0')), ('a203', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a204', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a205', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a206', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a207', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a208', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a209', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a210', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a211', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a212', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a213', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a214', 'B', 's1', ('Udine-Modena-0', 'Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Modena-0')), ('a215', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a216', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a217', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a218', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a219', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a220', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Venezia-0')), ('a221', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a222', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a223', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a224', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a225', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a226', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a227', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a228', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a229', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a230', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a231', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a232', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a233', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a234', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a235', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a236', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a237', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a238', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a239', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a240', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a241', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a242', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a243', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a244', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a245', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a246', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a247', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a248', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a249', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a250', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a251', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a252', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a253', 'J', 's1', ('Rome-Modena-0', 'Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0')), ('a254', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a255', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a256', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a257', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a258', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a259', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-3')), ('a260', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5', 'Trento-Padua-0')), ('a261', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a262', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a263', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a264', 'J', 's1', ('Verona-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a265', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Napoli-0', 'Napoli-Milano-0')), ('a266', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a267', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a268', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a269', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a270', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a271', 'J', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a272', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a273', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a274', 'J', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a275', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Bolzano-0', 'Bolzano-Trento-0', 'Trento-Genova-0')), ('a276', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a277', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a278', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a279', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a280', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a281', 'B', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Firenze-0', 'Firenze-Trento-0')), ('a282', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a283', 'E', 's1', ('Padua-Modena-0', 'Modena-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a284', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a285', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a286', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a287', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a288', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a289', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a290', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Padua-0')), ('a291', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a292', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a293', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a294', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a295', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a296', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-1')), ('a297', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a298', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a299', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6', 'Trento-Rome-0')), ('a300', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a301', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a302', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a303', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a304', 'B', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0')), ('a305', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a306', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a307', 'J', 's1', ('Modena-Verona-0', 'Verona-Genova-0', 'Genova-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a308', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a309', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a310', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a311', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a312', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a313', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a314', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a315', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a316', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a317', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a318', 'B', 's1', ('Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Milano-0', 'Milano-Trento-1')), ('a319', 'J', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Siena-0', 'Siena-Palermo-0', 'Palermo-Torino-0', 'Torino-Trento-0')), ('a320', 'B', 's1', ('Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a321', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a322', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a323', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a324', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a325', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a326', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a327', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a328', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a329', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a330', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a331', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Udine-0', 'Udine-Palermo-1', 'Palermo-Trento-3')), ('a332', 'J', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-1', 'Bergamo-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Trento-3')), ('a333', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a334', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a335', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a336', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a337', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a338', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a339', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a340', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a341', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a342', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a343', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a344', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a345', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a346', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a347', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a348', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a349', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a350', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a351', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a352', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a353', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a354', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a355', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a356', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a357', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a358', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a359', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a360', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a361', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a362', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a363', 'B', 's1', ('Bologna-Modena-0', 'Modena-Monza-0', 'Monza-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Venezia-0', 'Venezia-Trento-0')), ('a364', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a365', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a366', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a367', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a368', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a369', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a370', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a371', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Udine-0', 'Udine-Palermo-1', 'Palermo-Verona-0', 'Verona-Milano-0', 'Milano-Trento-0')), ('a372', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a373', 'B', 's1', ('Bolzano-Siena-0', 'Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a374', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a375', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a376', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a377', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a378', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a379', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a380', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Napoli-0', 'Napoli-Palermo-1', 'Palermo-Trento-0', 'Trento-Venezia-0')), ('a381', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5', 'Trento-Rome-0')), ('a382', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a383', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a384', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a385', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a386', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a387', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a388', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a389', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a390', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a391', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a392', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a393', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a394', 'J', 's1', ('Modena-Genova-0', 'Genova-Venezia-0', 'Venezia-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0')), ('a395', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a396', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a397', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a398', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a399', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a400', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a401', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a402', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a403', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a404', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a405', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a406', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Udine-0', 'Udine-Palermo-1', 'Palermo-Trento-3')), ('a407', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a408', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a409', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a410', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a411', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0', 'Trento-Padua-0')), ('a412', 'B', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Siena-0', 'Siena-Palermo-0', 'Palermo-Trento-0')), ('a413', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a414', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a415', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a416', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a417', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Palermo-1', 'Palermo-Trento-0')), ('a418', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a419', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a420', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a421', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a422', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a423', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a424', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0', 'Trento-Siena-0')), ('a425', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a426', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0')), ('a427', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a428', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-3')), ('a429', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a430', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a431', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a432', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a433', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a434', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a435', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a436', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a437', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a438', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a439', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a440', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a441', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a442', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a443', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a444', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a445', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a446', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a447', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a448', 'J', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Trento-1', 'Trento-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a449', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a450', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a451', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a452', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Siena-0', 'Siena-Palermo-0', 'Palermo-Trento-0')), ('a453', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a454', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a455', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a456', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a457', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a458', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a459', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Napoli-0', 'Napoli-Padua-0')), ('a460', 'J', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Bolzano-0', 'Bolzano-Milano-0', 'Milano-Trento-1')), ('a461', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a462', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a463', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3', 'Trento-Udine-0', 'Udine-Genova-5')), ('a464', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a465', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a466', 'J', 's1', ('Genova-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-0', 'Trento-Napoli-0')), ('a467', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a468', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a469', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a470', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a471', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a472', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a473', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a474', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a475', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a476', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a477', 'B', 's1', ('Lecce-Modena-0', 'Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a478', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a479', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a480', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a481', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-3')), ('a482', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a483', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a484', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a485', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a486', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a487', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a488', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a489', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a490', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Udine-0', 'Udine-Siena-0')), ('a491', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Verona-0', 'Verona-Genova-0')), ('a492', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a493', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a494', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a495', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a496', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a497', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a498', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a499', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a500', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a501', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-3')), ('a502', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a503', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a504', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a505', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a506', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a507', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a508', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a509', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a510', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a511', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a512', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a513', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a514', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a515', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a516', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a517', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a518', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a519', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a520', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a521', 'J', 's1', ('Udine-Lecce-0', 'Lecce-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a522', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a523', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a524', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a525', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a526', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a527', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a528', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a529', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a530', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a531', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a532', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-1')), ('a533', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a534', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-2')), ('a535', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a536', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a537', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a538', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a539', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a540', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a541', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a542', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a543', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a544', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a545', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a546', 'J', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Genova-0', 'Genova-Palermo-1', 'Palermo-Trento-0')), ('a547', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a548', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a549', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a550', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a551', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a552', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a553', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a554', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a555', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a556', 'J', 's1', ('Firenze-Verona-1', 'Verona-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a557', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a558', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a559', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a560', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a561', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a562', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a563', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a564', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a565', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a566', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a567', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a568', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a569', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a570', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a571', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a572', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a573', 'B', 's1', ('Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a574', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a575', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-1')), ('a576', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a577', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a578', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-3')), ('a579', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a580', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a581', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a582', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a583', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a584', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a585', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a586', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a587', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a588', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a589', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a590', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a591', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a592', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a593', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a594', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a595', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a596', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a597', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a598', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a599', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a600', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a601', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a602', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a603', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a604', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a605', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a606', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Lecce-0', 'Lecce-Rome-0', 'Rome-Trento-1')), ('a607', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a608', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a609', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a610', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a611', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a612', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a613', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a614', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a615', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a616', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a617', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a618', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a619', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a620', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a621', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a622', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a623', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a624', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a625', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a626', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a627', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a628', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a629', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a630', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-6')), ('a631', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-0', 'Palermo-Trento-3')), ('a632', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a633', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a634', 'J', 's1', ('Milano-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Bologna-0', 'Bologna-Palermo-0', 'Palermo-Trento-0', 'Trento-Genova-0')), ('a635', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a636', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a637', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a638', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a639', 'B', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a640', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a641', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a642', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a643', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a644', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a645', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a646', 'J', 's1', ('Siena-Modena-0', 'Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Pisa-0')), ('a647', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a648', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a649', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a650', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a651', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a652', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a653', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a654', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a655', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a656', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a657', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a658', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a659', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a660', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a661', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a662', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a663', 'B', 's1', ('Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Palermo-0', 'Palermo-Trento-0')), ('a664', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a665', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a666', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Siena-0', 'Siena-Palermo-0', 'Palermo-Trento-0', 'Trento-Modena-0', 'Modena-Torino-0')), ('a667', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a668', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a669', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a670', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a671', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a672', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a673', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a674', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a675', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a676', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a677', 'B', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0', 'Trento-Lecce-0')), ('a678', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a679', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0', 'Trento-Modena-0', 'Modena-Udine-0')), ('a680', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a681', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a682', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a683', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a684', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a685', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a686', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a687', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a688', 'J', 's1', ('Udine-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a689', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a690', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a691', 'J', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a692', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a693', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a694', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a695', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a696', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a697', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a698', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a699', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a700', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a701', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a702', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a703', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0')), ('a704', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a705', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a706', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a707', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a708', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a709', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a710', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a711', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a712', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4')), ('a713', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a714', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a715', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a716', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a717', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a718', 'B', 's1', ('Udine-Modena-0', 'Modena-Padua-0', 'Padua-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a719', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a720', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a721', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a722', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a723', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a724', 'B', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Trento-0')), ('a725', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a726', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a727', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a728', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a729', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-2')), ('a730', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a731', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a732', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a733', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a734', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a735', 'B', 's1', ('Pisa-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Firenze-1')), ('a736', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a737', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a738', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a739', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a740', 'J', 's1', ('Pisa-Modena-0', 'Modena-Monza-0', 'Monza-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Torino-0')), ('a741', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-5')), ('a742', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a743', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a744', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a745', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-2')), ('a746', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a747', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a748', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a749', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a750', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a751', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a752', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a753', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a754', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a755', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a756', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a757', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a758', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a759', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0', 'Trento-Verona-0')), ('a760', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a761', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a762', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a763', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a764', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0', 'Trento-Padua-0')), ('a765', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a766', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a767', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a768', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a769', 'J', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a770', 'J', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a771', 'J', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Firenze-4')), ('a772', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a773', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a774', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a775', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a776', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a777', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a778', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a779', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Torino-0')), ('a780', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a781', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a782', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a783', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a784', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a785', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a786', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a787', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a788', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a789', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a790', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a791', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a792', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a793', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a794', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a795', 'J', 's1', ('Monza-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a796', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a797', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a798', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a799', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a800', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a801', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0', 'Trento-Torino-0')), ('a802', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-1', 'Palermo-Trento-3', 'Trento-Torino-0', 'Torino-Siena-0')), ('a803', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a804', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Palermo-1', 'Palermo-Trento-0')), ('a805', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a806', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a807', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a808', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Torino-0')), ('a809', 'B', 's1', ('Modena-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Milano-0', 'Milano-Trento-1')), ('a810', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a811', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a812', 'B', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0')), ('a813', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a814', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a815', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a816', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a817', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a818', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a819', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a820', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a821', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a822', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a823', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a824', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a825', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a826', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a827', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a828', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a829', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a830', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a831', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a832', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a833', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a834', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a835', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a836', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a837', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a838', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a839', 'B', 's1', ('Modena-Verona-0', 'Verona-Palermo-1', 'Palermo-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a840', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a841', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a842', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a843', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a844', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a845', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a846', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a847', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a848', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a849', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Venezia-0', 'Venezia-Trento-1', 'Trento-Verona-0', 'Verona-Venezia-0')), ('a850', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a851', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Rome-0')), ('a852', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a853', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a854', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a855', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a856', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a857', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a858', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a859', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a860', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a861', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a862', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a863', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a864', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a865', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a866', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Udine-0', 'Udine-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Trento-0', 'Trento-Modena-0')), ('a867', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a868', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Siena-0', 'Siena-Udine-0', 'Udine-Trento-0', 'Trento-Pisa-0')), ('a869', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a870', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a871', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a872', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a873', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a874', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a875', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a876', 'J', 's1', ('Rome-Firenze-1', 'Firenze-Modena-0', 'Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a877', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a878', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-0')), ('a879', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Palermo-0', 'Palermo-Trento-0')), ('a880', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a881', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a882', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a883', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a884', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a885', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a886', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a887', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a888', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a889', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a890', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a891', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a892', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a893', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a894', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Verona-0', 'Verona-Trento-0')), ('a895', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a896', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a897', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a898', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a899', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a900', 'B', 's1', ('Napoli-Milano-0', 'Milano-Modena-0', 'Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a901', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a902', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a903', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a904', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a905', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a906', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a907', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a908', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-0')), ('a909', 'B', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-1', 'Palermo-Lecce-0', 'Lecce-Trento-0')), ('a910', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a911', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a912', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5', 'Trento-Padua-0')), ('a913', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a914', 'B', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a915', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a916', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a917', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a918', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a919', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a920', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a921', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a922', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a923', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a924', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a925', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a926', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a927', 'J', 's1', ('Modena-Monza-0', 'Monza-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Bolzano-0')), ('a928', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a929', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a930', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a931', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a932', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-2')), ('a933', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a934', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a935', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a936', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a937', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a938', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Monza-0', 'Monza-Napoli-0', 'Napoli-Trento-0')), ('a939', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a940', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a941', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a942', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a943', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a944', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a945', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a946', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a947', 'J', 's1', ('Torino-Modena-0', 'Modena-Firenze-0', 'Firenze-Monza-0', 'Monza-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a948', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Trento-0')), ('a949', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a950', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a951', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a952', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a953', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a954', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a955', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a956', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a957', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a958', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a959', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a960', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a961', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a962', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a963', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a964', 'B', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a965', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Padua-0', 'Padua-Trento-0')), ('a966', 'J', 's1', ('Modena-Siena-0', 'Siena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Bolzano-0')), ('a967', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a968', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a969', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a970', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a971', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a972', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a973', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a974', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a975', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a976', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a977', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a978', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a979', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a980', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a981', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a982', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Bologna-0', 'Bologna-Trento-0', 'Trento-Monza-0')), ('a983', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Siena-0', 'Siena-Trento-0', 'Trento-Genova-0', 'Genova-Napoli-0')), ('a984', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a985', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a986', 'J', 's1', ('Pisa-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a987', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a988', 'E', 's1', ('Rome-Modena-0', 'Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a989', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a990', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a991', 'B', 's1', ('Napoli-Bologna-0', 'Bologna-Modena-0', 'Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a992', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a993', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Verona-1', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a994', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a995', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a996', 'J', 's1', ('Venezia-Modena-0', 'Modena-Monza-0', 'Monza-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a997', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a998', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a999', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1000', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1001', 'B', 's1', ('Modena-Milano-0', 'Milano-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1002', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1003', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a1004', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1005', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1006', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1007', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1008', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1009', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1010', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1011', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1012', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1013', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1014', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1015', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1016', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1017', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1018', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1019', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1020', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1021', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1022', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1023', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1024', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1025', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1026', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1027', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1028', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1029', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1030', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1031', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1032', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1033', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1034', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1035', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1036', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1037', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1038', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0', 'Trento-Pisa-0')), ('a1039', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1040', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1041', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1042', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1043', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1044', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1045', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1046', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1047', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1048', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1049', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-3')), ('a1050', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1051', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1052', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Rome-0')), ('a1053', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1054', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-1')), ('a1055', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1056', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1057', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1058', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1059', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1060', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1061', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1062', 'B', 's1', ('Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-1', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a1063', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1064', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1065', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1066', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1067', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1068', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1069', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1070', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0', 'Trento-Bologna-2')), ('a1071', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1072', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1073', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1074', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1075', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Trento-0')), ('a1076', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1077', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1078', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1079', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1080', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1081', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1082', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1083', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-1')), ('a1084', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1085', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1086', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1087', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1088', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Padua-0')), ('a1089', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1090', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a1091', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1092', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1093', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1094', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1095', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1096', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1097', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-1')), ('a1098', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1099', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1100', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1101', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a1102', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1103', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1104', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1105', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1106', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1107', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1108', 'B', 's1', ('Monza-Bologna-0', 'Bologna-Modena-0', 'Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1109', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a1110', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Lecce-0', 'Lecce-Genova-0')), ('a1111', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1112', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a1113', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1114', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1115', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1116', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1117', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1118', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-1', 'Palermo-Trento-0')), ('a1119', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1120', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a1121', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1122', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1123', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1124', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1125', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1126', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Torino-0', 'Torino-Rome-0', 'Rome-Genova-0')), ('a1127', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1128', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1129', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1130', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1131', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1132', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1133', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1134', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1135', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1136', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1137', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1138', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1139', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1140', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1141', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1142', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1143', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1144', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1145', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1146', 'J', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1147', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1148', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a1149', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1150', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Pisa-0')), ('a1151', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1152', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a1153', 'B', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1154', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1155', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1156', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1157', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1158', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1159', 'J', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1160', 'J', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Torino-0', 'Torino-Milano-0', 'Milano-Trento-1')), ('a1161', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1162', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1163', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Firenze-0', 'Firenze-Trento-0', 'Trento-Monza-0', 'Monza-Napoli-0')), ('a1164', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1165', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-3')), ('a1166', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1167', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1168', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Siena-0', 'Siena-Trento-0', 'Trento-Napoli-0')), ('a1169', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1170', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1171', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1172', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1173', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1174', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1175', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1176', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1177', 'J', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1178', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1179', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bolzano-0', 'Bolzano-Napoli-0', 'Napoli-Verona-0', 'Verona-Trento-0')), ('a1180', 'J', 's1', ('Modena-Udine-0', 'Udine-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Torino-0', 'Torino-Trento-0')), ('a1181', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Trento-0')), ('a1182', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1183', 'J', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Udine-0', 'Udine-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a1184', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1185', 'B', 's1', ('Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a1186', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1187', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a1188', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1189', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Padua-0')), ('a1190', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1191', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1192', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1193', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1194', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1195', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1196', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1197', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1198', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1199', 'J', 's1', ('Udine-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-3')), ('a1200', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1201', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1202', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1203', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1204', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1205', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1206', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1207', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1208', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1209', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1210', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1211', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1212', 'J', 's1', ('Genova-Modena-0', 'Modena-Napoli-0', 'Napoli-Milano-0', 'Milano-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1213', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1214', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1215', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1216', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1217', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1218', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1219', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1220', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1221', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1222', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1223', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1224', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1225', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1226', 'J', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1227', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1228', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1229', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1230', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1231', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1232', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1233', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1234', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1235', 'J', 's1', ('Pisa-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-0')), ('a1236', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1237', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a1238', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1239', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1240', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1241', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Bologna-0', 'Bologna-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-3')), ('a1242', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1243', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1244', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1245', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1246', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1247', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1248', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1249', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1250', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1251', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1252', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1253', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1254', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1255', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1256', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1257', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1258', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1259', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1260', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1261', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3')), ('a1262', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1263', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1264', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1265', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1266', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1267', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1268', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1269', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1270', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Rome-0')), ('a1271', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1272', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1273', 'J', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Torino-0')), ('a1274', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1275', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1276', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1277', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1278', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Trento-0')), ('a1279', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1280', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1281', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1282', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1283', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1284', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1285', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1286', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1287', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1288', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1289', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1290', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1291', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1292', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1293', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1294', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1295', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1296', 'J', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1297', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1298', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1299', 'B', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a1300', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Padua-0')), ('a1301', 'J', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-0')), ('a1302', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Udine-0', 'Udine-Genova-5', 'Genova-Palermo-0', 'Palermo-Trento-0')), ('a1303', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1304', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1305', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1306', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1307', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1308', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1309', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1310', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1311', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1312', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1313', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1314', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1315', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1316', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1317', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1318', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1319', 'J', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Torino-0', 'Torino-Trento-0')), ('a1320', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1321', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1322', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1323', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1324', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1325', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1326', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1327', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1328', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a1329', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1330', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1331', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1332', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1333', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1334', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1335', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1336', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1337', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1338', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a1339', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a1340', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1341', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1342', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a1343', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1344', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1345', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1346', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Rome-0', 'Rome-Siena-0', 'Siena-Trento-1', 'Trento-Napoli-0')), ('a1347', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1348', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1349', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1350', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1351', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1352', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1353', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1354', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1355', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1356', 'J', 's1', ('Modena-Siena-0', 'Siena-Bologna-0', 'Bologna-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a1357', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1358', 'B', 's1', ('Modena-Padua-0', 'Padua-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1359', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1360', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1361', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-3')), ('a1362', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1363', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1364', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1365', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1366', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1367', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1368', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Milano-0', 'Milano-Trento-1', 'Trento-Rome-0')), ('a1369', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1370', 'J', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1371', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1372', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1373', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1374', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1375', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1376', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1377', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1378', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1379', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1380', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-1')), ('a1381', 'B', 's1', ('Modena-Bologna-0', 'Bologna-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1382', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1383', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1384', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1385', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1386', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1387', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1388', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1389', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1390', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1391', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1392', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1393', 'J', 's1', ('Modena-Genova-0', 'Genova-Bergamo-1', 'Bergamo-Monza-0', 'Monza-Udine-0', 'Udine-Palermo-1', 'Palermo-Trento-0')), ('a1394', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1395', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1396', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1397', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1398', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1399', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1400', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1401', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1402', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1403', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1404', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1405', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1406', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1407', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1408', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1409', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1410', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1411', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1412', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1413', 'J', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Verona-0', 'Verona-Bologna-0')), ('a1414', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1415', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1416', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1417', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1418', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1419', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a1420', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1421', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1422', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1423', 'B', 's1', ('Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a1424', 'J', 's1', ('Modena-Verona-0', 'Verona-Bergamo-1', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a1425', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1426', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-5')), ('a1427', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1428', 'B', 's1', ('Modena-Pisa-0', 'Pisa-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1429', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1430', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1431', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1432', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1433', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1434', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bolzano-0', 'Bolzano-Trento-1')), ('a1435', 'J', 's1', ('Padua-Milano-0', 'Milano-Modena-0', 'Modena-Siena-0', 'Siena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1436', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1437', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1438', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1439', 'J', 's1', ('Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Lecce-0')), ('a1440', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1441', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1442', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1443', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1444', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1445', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Verona-0', 'Verona-Monza-0', 'Monza-Padua-0')), ('a1446', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1447', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1448', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1449', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1450', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1451', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1452', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1453', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1454', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1455', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1456', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1457', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1458', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1459', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1460', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1461', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1462', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a1463', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1464', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1465', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1466', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1467', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1468', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1469', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Napoli-0', 'Napoli-Lecce-0', 'Lecce-Udine-0')), ('a1470', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1471', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1472', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Pisa-0')), ('a1473', 'B', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-1', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1474', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1475', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1476', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1477', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1478', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1479', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1480', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1481', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1482', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a1483', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1484', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1485', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a1486', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1487', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1488', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1489', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1490', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1491', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1492', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1493', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1494', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1495', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1496', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1497', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-0')), ('a1498', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1499', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1500', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1501', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1502', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1503', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1504', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1505', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1506', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1507', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1508', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1509', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1510', 'J', 's1', ('Udine-Modena-0', 'Modena-Venezia-0', 'Venezia-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1511', 'B', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1512', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1513', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1514', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1515', 'J', 's1', ('Modena-Pisa-0', 'Pisa-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1516', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1517', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Verona-0', 'Verona-Torino-0', 'Torino-Trento-0')), ('a1518', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1519', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1520', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1521', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1522', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1523', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1524', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1525', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1526', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1527', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-0')), ('a1528', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1529', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1530', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1531', 'B', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-0', 'Palermo-Trento-0', 'Trento-Venezia-0')), ('a1532', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1533', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1534', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a1535', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1536', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1537', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1538', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1539', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-6')), ('a1540', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1541', 'J', 's1', ('Modena-Rome-0', 'Rome-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a1542', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1543', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1544', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Bologna-0', 'Bologna-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3')), ('a1545', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Palermo-0', 'Palermo-Trento-0', 'Trento-Pisa-0', 'Pisa-Trento-0')), ('a1546', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1547', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1548', 'J', 's1', ('Modena-Pisa-0', 'Pisa-Udine-0', 'Udine-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1549', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Genova-0')), ('a1550', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1551', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1552', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1553', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1554', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1555', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1556', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1557', 'B', 's1', ('Verona-Pisa-0', 'Pisa-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Modena-0', 'Modena-Palermo-0', 'Palermo-Trento-0')), ('a1558', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1559', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a1560', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1561', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1562', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1563', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1564', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1565', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a1566', 'B', 's1', ('Venezia-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a1567', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1568', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1569', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a1570', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1571', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1572', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1573', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1574', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1575', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1576', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1577', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1578', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1579', 'E', 's1', ('Padua-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1580', 'J', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1581', 'E', 's1', ('Padua-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1582', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1583', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1584', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1585', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1586', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Padua-0', 'Padua-Trento-0')), ('a1587', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1588', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1589', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Pisa-0')), ('a1590', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1591', 'J', 's1', ('Udine-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1592', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1593', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-1', 'Trento-Rome-0')), ('a1594', 'J', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0')), ('a1595', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1596', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1597', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Udine-0', 'Udine-Palermo-1', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1598', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1599', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1600', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1601', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1602', 'J', 's1', ('Bologna-Modena-0', 'Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1603', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1604', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1605', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1606', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1607', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1608', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1609', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1610', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1611', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1612', 'B', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1613', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1614', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1615', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1616', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1617', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1618', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1619', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1620', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1621', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1622', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1623', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1624', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1625', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1626', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1627', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1628', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Padua-0')), ('a1629', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1630', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1631', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1632', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1633', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1634', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1635', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1636', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1637', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1638', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1639', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1640', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1641', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1642', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1643', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1644', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1645', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1646', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1647', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1648', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1649', 'B', 's1', ('Genova-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1650', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1651', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1652', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1653', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1654', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1655', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1656', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1657', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1658', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1659', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1660', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1661', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1662', 'J', 's1', ('Modena-Torino-0', 'Torino-Pisa-0', 'Pisa-Bergamo-1', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-0')), ('a1663', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1664', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a1665', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1666', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1667', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1668', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4')), ('a1669', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1670', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1671', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Udine-0', 'Udine-Trento-0', 'Trento-Venezia-0')), ('a1672', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1673', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1674', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1675', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1676', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1677', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1678', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1679', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1680', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a1681', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1682', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0', 'Udine-Firenze-4')), ('a1683', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1684', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a1685', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1686', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a1687', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1688', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1689', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a1690', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1691', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1692', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1693', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1694', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1695', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a1696', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1697', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1698', 'J', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a1699', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1700', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1701', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1702', 'B', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1703', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1704', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1705', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1706', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1707', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1708', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1709', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1710', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1711', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1712', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1713', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1714', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1715', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1716', 'B', 's1', ('Bolzano-Firenze-0', 'Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1717', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1718', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1719', 'E', 's1', ('Modena-Rome-0', 'Rome-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1720', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1721', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1722', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1723', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a1724', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Trento-0', 'Trento-Lecce-0', 'Lecce-Firenze-0')), ('a1725', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1726', 'E', 's1', ('Rome-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1727', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1728', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1729', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1730', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1731', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1732', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1733', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1734', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1735', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1736', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Padua-0', 'Padua-Trento-2')), ('a1737', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1738', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1739', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1740', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Pisa-0')), ('a1741', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1742', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1743', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1744', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1745', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1746', 'J', 's1', ('Bologna-Modena-0', 'Modena-Napoli-0', 'Napoli-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Lecce-0', 'Lecce-Trento-0')), ('a1747', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1748', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1749', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0')), ('a1750', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1751', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1752', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1753', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1754', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1755', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1756', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1757', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1758', 'B', 's1', ('Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1759', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1760', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1761', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1762', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1763', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1764', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1765', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1766', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1767', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1768', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1769', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1770', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1771', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1772', 'J', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bolzano-0', 'Bolzano-Trento-1', 'Trento-Verona-0')), ('a1773', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a1774', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1775', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1776', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1777', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1778', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1779', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1780', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1781', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1782', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1783', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1784', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1785', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a1786', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1787', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1788', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1789', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1790', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1791', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1792', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1793', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1794', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1795', 'J', 's1', ('Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Siena-0', 'Siena-Palermo-0', 'Palermo-Bolzano-0', 'Bolzano-Trento-0')), ('a1796', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1797', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1798', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1799', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1800', 'B', 's1', ('Siena-Modena-0', 'Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1801', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1802', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1803', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1804', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1805', 'J', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a1806', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1807', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1808', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1809', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1810', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Pisa-0', 'Pisa-Siena-0')), ('a1811', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a1812', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1813', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1814', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1815', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1816', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1817', 'J', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1818', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1819', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1820', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1821', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1822', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1823', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-1')), ('a1824', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1825', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1826', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1827', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1828', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1829', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1830', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1831', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Palermo-0', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a1832', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1833', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Siena-0', 'Siena-Bologna-0', 'Bologna-Trento-0')), ('a1834', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1835', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1836', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1837', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1838', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1839', 'B', 's1', ('Modena-Torino-0', 'Torino-Bologna-0', 'Bologna-Bergamo-1', 'Bergamo-Firenze-0', 'Firenze-Palermo-1', 'Palermo-Trento-0')), ('a1840', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1841', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1842', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1843', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1844', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1845', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1846', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1847', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1848', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1849', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1850', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1851', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a1852', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1853', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1854', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1855', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1856', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-6')), ('a1857', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a1858', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-1')), ('a1859', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1860', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1861', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1862', 'J', 's1', ('Lecce-Bolzano-0', 'Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1863', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1864', 'B', 's1', ('Siena-Bolzano-0', 'Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1865', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1866', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1867', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1868', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1869', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1870', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1871', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1872', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1873', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1874', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1875', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1876', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1877', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1878', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a1879', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a1880', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1881', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1882', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1883', 'B', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Genova-0', 'Genova-Trento-0', 'Trento-Udine-0')), ('a1884', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1885', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1886', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1887', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1888', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1889', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1890', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1891', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1892', 'J', 's1', ('Pisa-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1893', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1894', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1895', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Torino-0', 'Torino-Udine-0')), ('a1896', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1897', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1898', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1899', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Lecce-0', 'Lecce-Trento-0')), ('a1900', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1901', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1902', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1903', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a1904', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Bologna-0', 'Bologna-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1905', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1906', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1907', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1908', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1909', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1910', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1911', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1912', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1913', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1914', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1915', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1916', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1917', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1918', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1919', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1920', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1921', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-5')), ('a1922', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1923', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1924', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1925', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1926', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1927', 'B', 's1', ('Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Monza-0', 'Monza-Trento-0')), ('a1928', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a1929', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1930', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1931', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1932', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1933', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a1934', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1935', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-1')), ('a1936', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1937', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Bolzano-0', 'Bolzano-Trento-0')), ('a1938', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1939', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a1940', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1941', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1942', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a1943', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1944', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1945', 'B', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0', 'Trento-Palermo-0')), ('a1946', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1947', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1948', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1949', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1950', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a1951', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Palermo-0', 'Palermo-Monza-0', 'Monza-Trento-0', 'Trento-Firenze-4')), ('a1952', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-1', 'Palermo-Trento-0')), ('a1953', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1954', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1955', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1956', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1957', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-0', 'Palermo-Trento-0', 'Trento-Bolzano-0')), ('a1958', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Padua-0', 'Padua-Trento-1')), ('a1959', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1960', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a1961', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1962', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1963', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1964', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1965', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a1966', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1967', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1968', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1969', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a1970', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a1971', 'B', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0')), ('a1972', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1973', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1974', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1975', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1976', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1977', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1978', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a1979', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a1980', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1981', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1982', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1983', 'B', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a1984', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1985', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a1986', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1987', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1988', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a1989', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-5', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1990', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1991', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a1992', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1993', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a1994', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1995', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a1996', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0', 'Trento-Modena-0')), ('a1997', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a1998', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a1999', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2000', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2001', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2002', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a2003', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Lecce-0', 'Lecce-Napoli-0', 'Napoli-Genova-1', 'Genova-Palermo-1', 'Palermo-Trento-0')), ('a2004', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2005', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2006', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2007', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2008', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2009', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2010', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2011', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2012', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2013', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2014', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2015', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a2016', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2017', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2018', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2019', 'B', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-0', 'Palermo-Trento-0')), ('a2020', 'E', 's1', ('Padua-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2021', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1', 'Trento-Verona-0')), ('a2022', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2023', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2024', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2025', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2026', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2027', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2028', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2029', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2030', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Bologna-1')), ('a2031', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2032', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2033', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2034', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2035', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2036', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2037', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2038', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2039', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2040', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2041', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2042', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2043', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2044', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2045', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-1', 'Palermo-Trento-0', 'Trento-Lecce-0', 'Lecce-Genova-0')), ('a2046', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2047', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2048', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2049', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2050', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2051', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2052', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2053', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2054', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2055', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Rome-0', 'Rome-Padua-0')), ('a2056', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2057', 'J', 's1', ('Monza-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Udine-0', 'Udine-Palermo-1', 'Palermo-Trento-3')), ('a2058', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2059', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2060', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2061', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2062', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2063', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-3')), ('a2064', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2065', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2066', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a2067', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2068', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2069', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2070', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2071', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2072', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2073', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2074', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2075', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a2076', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2077', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2078', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2079', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2080', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2081', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2082', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-6')), ('a2083', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2084', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2085', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2086', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Palermo-1', 'Palermo-Lecce-0', 'Lecce-Bolzano-0', 'Bolzano-Trento-1')), ('a2087', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2088', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2089', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2090', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2091', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2092', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2093', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-1', 'Trento-Rome-0')), ('a2094', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2095', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2096', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2097', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2098', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2099', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2100', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2101', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2102', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0', 'Trento-Rome-0')), ('a2103', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2104', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2105', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-3')), ('a2106', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2107', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2108', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2109', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2110', 'J', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2111', 'E', 's1', ('Padua-Modena-0', 'Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2112', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Napoli-0', 'Napoli-Palermo-0', 'Palermo-Trento-3', 'Trento-Lecce-0')), ('a2113', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2114', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2115', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a2116', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2117', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2118', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2119', 'J', 's1', ('Modena-Udine-0', 'Udine-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Bolzano-0')), ('a2120', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2121', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2122', 'J', 's1', ('Monza-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Lecce-0')), ('a2123', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Pisa-0', 'Pisa-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Trento-3')), ('a2124', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2125', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2126', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2127', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2128', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2129', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a2130', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2131', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Padua-0')), ('a2132', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2133', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2134', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2135', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2136', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2137', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2138', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2139', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2140', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a2141', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2142', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2143', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2144', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2145', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4')), ('a2146', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2147', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2148', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2149', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2150', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2151', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2152', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2153', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2154', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2155', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2156', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2157', 'B', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a2158', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2159', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2160', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2161', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2162', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2163', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2164', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2165', 'J', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Modena-0', 'Modena-Palermo-0', 'Palermo-Trento-0', 'Trento-Venezia-0')), ('a2166', 'J', 's1', ('Modena-Firenze-0', 'Firenze-Rome-0', 'Rome-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2167', 'J', 's1', ('Modena-Napoli-0', 'Napoli-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2168', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a2169', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Milano-0', 'Milano-Udine-0', 'Udine-Trento-0', 'Trento-Torino-0')), ('a2170', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2171', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2172', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2173', 'B', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2174', 'B', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Pisa-0', 'Pisa-Bologna-0')), ('a2175', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2176', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-1')), ('a2177', 'J', 's1', ('Monza-Udine-0', 'Udine-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-0')), ('a2178', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2179', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2180', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2181', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2182', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2183', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a2184', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2185', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Bologna-1')), ('a2186', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2187', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a2188', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2189', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2190', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2191', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2192', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2193', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2194', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2195', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2196', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2197', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2198', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2199', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2200', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2201', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2202', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2203', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2204', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2205', 'B', 's1', ('Milano-Modena-0', 'Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Firenze-0', 'Firenze-Trento-0')), ('a2206', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2207', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2208', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2209', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2210', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2211', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2212', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2213', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a2214', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2215', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a2216', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2217', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2218', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2219', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2220', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2221', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2222', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a2223', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2224', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2225', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2226', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Monza-0', 'Monza-Genova-0', 'Genova-Napoli-0')), ('a2227', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2228', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2229', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2230', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Torino-0', 'Torino-Bologna-0', 'Bologna-Trento-0')), ('a2231', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2232', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2233', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2234', 'B', 's1', ('Bolzano-Modena-0', 'Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2235', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2236', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2237', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2238', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2239', 'B', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Pisa-0')), ('a2240', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2241', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2242', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2243', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2244', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2245', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2246', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2247', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2248', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2249', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2250', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2251', 'B', 's1', ('Palermo-Napoli-0', 'Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a2252', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2253', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2254', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a2255', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2256', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2257', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2258', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2259', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2260', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2261', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2262', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2263', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2264', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a2265', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2266', 'B', 's1', ('Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Monza-0', 'Monza-Trento-0')), ('a2267', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2268', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Palermo-0', 'Palermo-Trento-0')), ('a2269', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a2270', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2271', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2272', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2273', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2274', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2275', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2276', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2277', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a2278', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Padua-0', 'Padua-Verona-0', 'Verona-Trento-0', 'Trento-Udine-0')), ('a2279', 'J', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Monza-0', 'Monza-Trento-0')), ('a2280', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2281', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2282', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Monza-0', 'Monza-Trento-1')), ('a2283', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2284', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2285', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2286', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2287', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2288', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2289', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2290', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2291', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Firenze-0', 'Firenze-Padua-0', 'Padua-Trento-0')), ('a2292', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2293', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Padua-0', 'Padua-Trento-1')), ('a2294', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2295', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2296', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2297', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2298', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Lecce-0', 'Lecce-Trento-0', 'Trento-Bolzano-0')), ('a2299', 'B', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2300', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2301', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2302', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2303', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2304', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2305', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2306', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2307', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2308', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2309', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2310', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2311', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2312', 'J', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2313', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2314', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2315', 'B', 's1', ('Siena-Modena-0', 'Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2316', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2317', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2318', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2319', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Monza-0', 'Monza-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2320', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2321', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2322', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2323', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Trento-3')), ('a2324', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2325', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2326', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2327', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2328', 'E', 's1', ('Rome-Modena-0', 'Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2329', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2330', 'B', 's1', ('Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Rome-0', 'Rome-Trento-0', 'Trento-Modena-0')), ('a2331', 'J', 's1', ('Monza-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a2332', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2333', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2334', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2335', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2336', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2337', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2338', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2339', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2340', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2341', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2342', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2343', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2344', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2345', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2346', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-1', 'Palermo-Trento-0', 'Trento-Lecce-0', 'Lecce-Venezia-0')), ('a2347', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Genova-0')), ('a2348', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Pisa-0')), ('a2349', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2350', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2351', 'J', 's1', ('Modena-Trento-0', 'Trento-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Genova-0', 'Genova-Milano-0')), ('a2352', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2353', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2354', 'B', 's1', ('Modena-Torino-0', 'Torino-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2355', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2356', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2357', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Lecce-0', 'Lecce-Trento-0', 'Trento-Padua-0')), ('a2358', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2359', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Modena-0', 'Modena-Genova-0')), ('a2360', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2361', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2362', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2363', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2364', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2365', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2366', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2367', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2368', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Verona-0', 'Verona-Trento-0')), ('a2369', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2370', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2371', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2372', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2373', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2374', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a2375', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2376', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-1', 'Trento-Padua-0')), ('a2377', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2378', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3', 'Trento-Rome-0')), ('a2379', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1', 'Trento-Milano-0')), ('a2380', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2381', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2382', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2383', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2384', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2385', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2386', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2387', 'J', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a2388', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2389', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2390', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Bolzano-0', 'Bolzano-Trento-0', 'Trento-Torino-0', 'Torino-Venezia-0')), ('a2391', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2392', 'B', 's1', ('Milano-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2393', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2394', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2395', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2396', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2397', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2398', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2399', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2400', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2401', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2402', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2403', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Bolzano-0')), ('a2404', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2405', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2406', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2407', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2408', 'B', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2409', 'B', 's1', ('Napoli-Milano-0', 'Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2410', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2411', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2412', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2413', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Siena-0', 'Siena-Trento-0', 'Trento-Bergamo-0', 'Bergamo-Lecce-0')), ('a2414', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2415', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2416', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2417', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2418', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-2')), ('a2419', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2420', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2421', 'B', 's1', ('Venezia-Modena-0', 'Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Palermo-1', 'Palermo-Trento-0')), ('a2422', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2423', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2424', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2425', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2426', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2427', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2428', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2429', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2430', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Padua-0', 'Padua-Trento-0')), ('a2431', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2432', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2433', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-0')), ('a2434', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2435', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2436', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2437', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2438', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2439', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2440', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2441', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2442', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2443', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2444', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2445', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a2446', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2447', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a2448', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a2449', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2450', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2451', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2452', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2453', 'J', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Milano-0', 'Milano-Trento-0')), ('a2454', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2455', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2456', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2457', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2458', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2459', 'B', 's1', ('Napoli-Lecce-0', 'Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a2460', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2461', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2462', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2463', 'B', 's1', ('Firenze-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-1', 'Palermo-Trento-0')), ('a2464', 'J', 's1', ('Modena-Monza-0', 'Monza-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2465', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2466', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2467', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2468', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2469', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4')), ('a2470', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2471', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2472', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2473', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Padua-0')), ('a2474', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2475', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2476', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a2477', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2478', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2479', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2480', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2481', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2482', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2483', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2484', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2485', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2486', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2487', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2488', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2489', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2490', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2491', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2492', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2493', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2494', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2495', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2496', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2497', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2498', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2499', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2500', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2501', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Siena-0', 'Siena-Firenze-0', 'Firenze-Siena-0')), ('a2502', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2503', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2504', 'B', 's1', ('Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2505', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-6', 'Trento-Padua-0')), ('a2506', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-5', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-5')), ('a2507', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2508', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2509', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2510', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2511', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Udine-0', 'Udine-Palermo-1', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2512', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2513', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2514', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2515', 'J', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Lecce-0', 'Lecce-Trento-0')), ('a2516', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2517', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2518', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Rome-0')), ('a2519', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a2520', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2521', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2522', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2523', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2524', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2525', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2526', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2527', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2528', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2529', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a2530', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a2531', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2532', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2533', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2534', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2535', 'B', 's1', ('Verona-Trento-0', 'Trento-Modena-0', 'Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2536', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2537', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2538', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Venezia-0', 'Venezia-Trento-1')), ('a2539', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0', 'Padua-Modena-0', 'Modena-Lecce-0')), ('a2540', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a2541', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Torino-0', 'Torino-Pisa-0')), ('a2542', 'B', 's1', ('Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Lecce-0')), ('a2543', 'B', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a2544', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a2545', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2546', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Trento-1', 'Trento-Milano-0')), ('a2547', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2548', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2549', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2550', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2551', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2552', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2553', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2554', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2555', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2556', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2557', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Firenze-3')), ('a2558', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2559', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2560', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2561', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2562', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2563', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2564', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2565', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Verona-0')), ('a2566', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2567', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2568', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2569', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2570', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2571', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2572', 'B', 's1', ('Pisa-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2573', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2574', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2575', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2576', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2577', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2578', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2579', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2580', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2581', 'J', 's1', ('Udine-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2582', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2583', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2584', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2585', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2586', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2587', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2588', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Trento-3')), ('a2589', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2590', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2591', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2592', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2593', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2594', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2595', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2596', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2597', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2598', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2599', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2600', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a2601', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2602', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2603', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2604', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-0')), ('a2605', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2606', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2607', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6', 'Trento-Padua-0', 'Padua-Rome-0')), ('a2608', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2609', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2610', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2611', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2612', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2613', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2614', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2615', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2616', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-3', 'Trento-Firenze-3')), ('a2617', 'B', 's1', ('Udine-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2618', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2619', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-0')), ('a2620', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a2621', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2622', 'B', 's1', ('Monza-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-0', 'Palermo-Trento-0')), ('a2623', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Torino-0', 'Torino-Trento-1', 'Trento-Verona-0')), ('a2624', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2625', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2626', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2627', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Torino-0', 'Torino-Trento-1')), ('a2628', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2629', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2630', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-0', 'Palermo-Trento-0')), ('a2631', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2632', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2633', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a2634', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a2635', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2636', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2637', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2638', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a2639', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2640', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2641', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2642', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2643', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2644', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2645', 'J', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2646', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2647', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2648', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2649', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Napoli-0')), ('a2650', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2651', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2652', 'B', 's1', ('Lecce-Siena-0', 'Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Venezia-0', 'Venezia-Trento-0')), ('a2653', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2654', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2655', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2656', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2657', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2658', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2659', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-1')), ('a2660', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2661', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2662', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2663', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2664', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2665', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2666', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2667', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2668', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2669', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Monza-0', 'Monza-Milano-0', 'Milano-Trento-1')), ('a2670', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2671', 'J', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0')), ('a2672', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2673', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2674', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2675', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2676', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2677', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2678', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2679', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2680', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2681', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2682', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2683', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2684', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2685', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a2686', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2687', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-0')), ('a2688', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2689', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2690', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2691', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Udine-0', 'Udine-Trento-0', 'Trento-Firenze-3')), ('a2692', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2693', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a2694', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2695', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2696', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2697', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2698', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2699', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2700', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2701', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2702', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2703', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2704', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Lecce-0', 'Lecce-Torino-0', 'Torino-Trento-1')), ('a2705', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2706', 'B', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0', 'Trento-Venezia-0')), ('a2707', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-1')), ('a2708', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2709', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2710', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2711', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a2712', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2713', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2714', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2715', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2716', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2717', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2718', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2719', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2720', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2721', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2722', 'J', 's1', ('Modena-Pisa-0', 'Pisa-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2723', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2724', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a2725', 'B', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Genova-2')), ('a2726', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2727', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2728', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2729', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2730', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2731', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2732', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2733', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2734', 'B', 's1', ('Monza-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2735', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2736', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2737', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2738', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2739', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2740', 'J', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a2741', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2742', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2743', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Udine-0', 'Udine-Monza-0', 'Monza-Trento-0', 'Trento-Milano-0')), ('a2744', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Monza-0', 'Monza-Milano-0', 'Milano-Trento-1', 'Trento-Bologna-1')), ('a2745', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2746', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2747', 'J', 's1', ('Verona-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0')), ('a2748', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2749', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2750', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2751', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2752', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2753', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2754', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Venezia-0', 'Venezia-Trento-0')), ('a2755', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2756', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2757', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2758', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2759', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2760', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Siena-0')), ('a2761', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2762', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2763', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2764', 'B', 's1', ('Firenze-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2765', 'B', 's1', ('Modena-Siena-0', 'Siena-Modena-0', 'Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2766', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2767', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2768', 'J', 's1', ('Modena-Siena-0', 'Siena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Bolzano-0')), ('a2769', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a2770', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Torino-0')), ('a2771', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2772', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2773', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2774', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2775', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2776', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2777', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2778', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a2779', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a2780', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2781', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2782', 'B', 's1', ('Modena-Pisa-0', 'Pisa-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Bolzano-0')), ('a2783', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2784', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2785', 'B', 's1', ('Udine-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a2786', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Lecce-0', 'Lecce-Trento-1')), ('a2787', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2788', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2789', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2790', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-5')), ('a2791', 'B', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-0', 'Palermo-Trento-0')), ('a2792', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2793', 'J', 's1', ('Modena-Pisa-0', 'Pisa-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a2794', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2795', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2796', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2797', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a2798', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2799', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2800', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2801', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2802', 'J', 's1', ('Modena-Milano-0', 'Milano-Bologna-0', 'Bologna-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Lecce-0')), ('a2803', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2804', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2805', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2806', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2807', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2808', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2809', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a2810', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2811', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2812', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2813', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2814', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2815', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Bologna-2')), ('a2816', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2817', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2818', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2819', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2820', 'B', 's1', ('Rome-Pisa-0', 'Pisa-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Modena-0', 'Modena-Trento-0')), ('a2821', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2822', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2823', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2824', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2825', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2826', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2827', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2828', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2829', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2830', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2831', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a2832', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2833', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2834', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2835', 'J', 's1', ('Verona-Genova-0', 'Genova-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2836', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2837', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2838', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2839', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2840', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2841', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2842', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2843', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2844', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2845', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2846', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2847', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2848', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2849', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2850', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2851', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Palermo-0', 'Palermo-Trento-0')), ('a2852', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2853', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0', 'Padua-Rome-0')), ('a2854', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2855', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2856', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2857', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2858', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-5')), ('a2859', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2860', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2861', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2862', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2863', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2864', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2865', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2866', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2867', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2868', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2869', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2870', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2871', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2872', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2873', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2874', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Bolzano-0', 'Bolzano-Monza-0', 'Monza-Trento-0')), ('a2875', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2876', 'E', 's1', ('Rome-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2877', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2878', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2879', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2880', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2881', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2882', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2883', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2884', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Genova-0')), ('a2885', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2886', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2887', 'B', 's1', ('Pisa-Modena-0', 'Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-0', 'Palermo-Trento-0')), ('a2888', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2889', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2890', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2891', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2892', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2893', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2894', 'J', 's1', ('Modena-Monza-0', 'Monza-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2895', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2896', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2897', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2898', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2899', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2900', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2901', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a2902', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2903', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2904', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2905', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a2906', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2907', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2908', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2909', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2910', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2911', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2912', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2913', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a2914', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2915', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2916', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2917', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2918', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2919', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2920', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2921', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Napoli-0', 'Napoli-Torino-0', 'Torino-Trento-1')), ('a2922', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2923', 'J', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-3')), ('a2924', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2925', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2926', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2927', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a2928', 'J', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Siena-0', 'Siena-Palermo-0', 'Palermo-Trento-3')), ('a2929', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2930', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a2931', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2932', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a2933', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2934', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2935', 'J', 's1', ('Genova-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2936', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2937', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2938', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2939', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2940', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2941', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2942', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Bolzano-0')), ('a2943', 'J', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Napoli-0')), ('a2944', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2945', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2946', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a2947', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-3')), ('a2948', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a2949', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2950', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2951', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2952', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2953', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a2954', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2955', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2956', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2957', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2958', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2959', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2960', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2961', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2962', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a2963', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2964', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2965', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2966', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2967', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2968', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2969', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2970', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2971', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a2972', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Pisa-0', 'Pisa-Palermo-1', 'Palermo-Napoli-0')), ('a2973', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2974', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2975', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2976', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2977', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2978', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2979', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2980', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a2981', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2982', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a2983', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2984', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2985', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2986', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2987', 'B', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a2988', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a2989', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a2990', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a2991', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2992', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2993', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a2994', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a2995', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a2996', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a2997', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a2998', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a2999', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3000', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a3001', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3002', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3003', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0', 'Padua-Siena-0')), ('a3004', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3005', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3006', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3007', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3008', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3009', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3010', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3011', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3012', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3013', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3014', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3015', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3016', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Milano-0', 'Milano-Trento-1', 'Trento-Verona-0', 'Verona-Palermo-0')), ('a3017', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3018', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3019', 'J', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3020', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3021', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a3022', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3023', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-6', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3024', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3025', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3026', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3027', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3028', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3029', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a3030', 'J', 's1', ('Modena-Napoli-0', 'Napoli-Monza-0', 'Monza-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3031', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3032', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3033', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3034', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a3035', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3036', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3037', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3038', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3039', 'B', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3040', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3041', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Milano-0', 'Milano-Udine-0', 'Udine-Trento-0')), ('a3042', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3043', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3044', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3045', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3046', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3047', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3048', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3049', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3050', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a3051', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3052', 'B', 's1', ('Modena-Genova-0', 'Genova-Firenze-0', 'Firenze-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3053', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3054', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3055', 'B', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Siena-0', 'Siena-Trento-0')), ('a3056', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3057', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3058', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3059', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-5')), ('a3060', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3061', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3062', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3063', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3064', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a3065', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a3066', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a3067', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3068', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3069', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3070', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3071', 'J', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Rome-0', 'Rome-Firenze-1')), ('a3072', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3073', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3074', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3075', 'J', 's1', ('Pisa-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Firenze-3')), ('a3076', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3077', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3078', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3079', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3080', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3081', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3082', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3083', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3084', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3085', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3086', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3087', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3088', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3089', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3090', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3091', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3092', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3093', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3094', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3095', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a3096', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3097', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3098', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3099', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3100', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3101', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3102', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3103', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3104', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3105', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3106', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3107', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6', 'Trento-Rome-0')), ('a3108', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3109', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3110', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0')), ('a3111', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3112', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3113', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3114', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3115', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3116', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3117', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3118', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3119', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3120', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3121', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3122', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3123', 'J', 's1', ('Bologna-Modena-0', 'Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3124', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Lecce-0', 'Lecce-Trento-0')), ('a3125', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3126', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3127', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3128', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3129', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3130', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3131', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3132', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3133', 'J', 's1', ('Venezia-Firenze-0', 'Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Genova-2')), ('a3134', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3135', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3136', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3137', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Genova-0')), ('a3138', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3139', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3140', 'E', 's1', ('Rome-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3141', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Napoli-0', 'Napoli-Trento-0')), ('a3142', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3143', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Torino-0')), ('a3144', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3145', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3146', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a3147', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3148', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-3')), ('a3149', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3150', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3151', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3152', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3153', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3154', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3155', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3156', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-1', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a3157', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3158', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a3159', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a3160', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3161', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3162', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3163', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3164', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3165', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Siena-0')), ('a3166', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3167', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3168', 'J', 's1', ('Modena-Milano-0', 'Milano-Bolzano-0', 'Bolzano-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3169', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3170', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a3171', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3172', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3173', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3174', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3175', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3176', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3177', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3178', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-3')), ('a3179', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3180', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3181', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3182', 'E', 's1', ('Padua-Modena-0', 'Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3183', 'B', 's1', ('Modena-Genova-0', 'Genova-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3184', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3185', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3186', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Torino-0', 'Torino-Trento-0')), ('a3187', 'B', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3188', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3189', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3190', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3191', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3192', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3193', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3194', 'E', 's1', ('Rome-Modena-0', 'Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3195', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3196', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3197', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3198', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3199', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a3200', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3201', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a3202', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3203', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3204', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a3205', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3206', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3207', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Modena-0', 'Modena-Trento-0')), ('a3208', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3209', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3210', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Firenze-0', 'Firenze-Trento-0', 'Trento-Napoli-0')), ('a3211', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3212', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3213', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Milano-0', 'Milano-Trento-1', 'Trento-Siena-0', 'Siena-Monza-0')), ('a3214', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3215', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3216', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3217', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3218', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3219', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3220', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Firenze-4', 'Firenze-Napoli-0')), ('a3221', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3222', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3223', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3224', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3225', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3226', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3227', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3228', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3229', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3230', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3231', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3232', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3233', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3234', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3235', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3236', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3237', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3238', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-2')), ('a3239', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3240', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3241', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a3242', 'J', 's1', ('Napoli-Modena-0', 'Modena-Padua-0', 'Padua-Pisa-0', 'Pisa-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3243', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3244', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3245', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3246', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3247', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3248', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Venezia-0', 'Venezia-Trento-1')), ('a3249', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3250', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3251', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3252', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3253', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3254', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3255', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3256', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3257', 'J', 's1', ('Rome-Venezia-0', 'Venezia-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a3258', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3259', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3260', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3261', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3262', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3263', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a3264', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3265', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3266', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3267', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3268', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3269', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3270', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3271', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3272', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3273', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3274', 'B', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3275', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3276', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3277', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3278', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3279', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Bologna-1')), ('a3280', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3281', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3282', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3283', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3284', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3285', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Lecce-0', 'Lecce-Trento-1')), ('a3286', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3287', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3288', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3289', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3290', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3291', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3292', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3293', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3294', 'J', 's1', ('Monza-Siena-0', 'Siena-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Lecce-0')), ('a3295', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3296', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3297', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3298', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3299', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3300', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3301', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3302', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3303', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3304', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3305', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Monza-0', 'Monza-Trento-1', 'Trento-Milano-0')), ('a3306', 'J', 's1', ('Milano-Venezia-0', 'Venezia-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a3307', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3308', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3309', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3310', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3311', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-3')), ('a3312', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3313', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6', 'Trento-Padua-0')), ('a3314', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3315', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3316', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3317', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3318', 'J', 's1', ('Modena-Genova-0', 'Genova-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-0', 'Trento-Torino-0')), ('a3319', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3320', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Padua-0', 'Padua-Trento-0', 'Trento-Pisa-0')), ('a3321', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3')), ('a3322', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3323', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3324', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3325', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3326', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a3327', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3328', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3329', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3330', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a3331', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3332', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3333', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3334', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3335', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3336', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3337', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Rome-0', 'Rome-Napoli-0', 'Napoli-Trento-0')), ('a3338', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3339', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3340', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3341', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3342', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a3343', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3344', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3345', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3346', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3347', 'B', 's1', ('Padua-Modena-0', 'Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3348', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3349', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3350', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3351', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3352', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3353', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3354', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Lecce-0', 'Lecce-Trento-0')), ('a3355', 'B', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a3356', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3357', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3358', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3359', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3360', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3361', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3362', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3363', 'B', 's1', ('Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-0', 'Trento-Siena-0')), ('a3364', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3365', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3366', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3367', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3368', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3369', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3370', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a3371', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3372', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3373', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3374', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3375', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3376', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-2')), ('a3377', 'J', 's1', ('Venezia-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Udine-0', 'Udine-Milano-0', 'Milano-Palermo-0', 'Palermo-Trento-0')), ('a3378', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3379', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3380', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3381', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3382', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3383', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Bolzano-0', 'Bolzano-Genova-0', 'Genova-Pisa-0', 'Pisa-Trento-1')), ('a3384', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Monza-0', 'Monza-Trento-0', 'Trento-Verona-0')), ('a3385', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3386', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3387', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3388', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3389', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3390', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Udine-0', 'Udine-Padua-0', 'Padua-Trento-0')), ('a3391', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3392', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3393', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3394', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3395', 'B', 's1', ('Venezia-Firenze-0', 'Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3396', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3397', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3398', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3399', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-3')), ('a3400', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3401', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3402', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3403', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3404', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3405', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3406', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3407', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3408', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3409', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3410', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3411', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3412', 'J', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Siena-0', 'Siena-Torino-0')), ('a3413', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a3414', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3415', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3416', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a3417', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Verona-0')), ('a3418', 'J', 's1', ('Bologna-Firenze-0', 'Firenze-Modena-0', 'Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3419', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3420', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3421', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3422', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3423', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3424', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Venezia-0', 'Venezia-Trento-1')), ('a3425', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3426', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3427', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3428', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3429', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3430', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Napoli-0')), ('a3431', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3432', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a3433', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3434', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3435', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3436', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3437', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3438', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3439', 'J', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Monza-0', 'Monza-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-3')), ('a3440', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3441', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3442', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3443', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3444', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a3445', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3446', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3447', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3448', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3449', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3450', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5', 'Trento-Rome-0')), ('a3451', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3452', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3453', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3454', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Torino-0', 'Torino-Rome-0')), ('a3455', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-0')), ('a3456', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3457', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3458', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Monza-0', 'Monza-Trento-0')), ('a3459', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3460', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3461', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3462', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3463', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3464', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3465', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3466', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3467', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3468', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3469', 'B', 's1', ('Modena-Monza-0', 'Monza-Bergamo-1', 'Bergamo-Genova-0', 'Genova-Palermo-0', 'Palermo-Trento-0')), ('a3470', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3471', 'B', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3472', 'J', 's1', ('Firenze-Rome-0', 'Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Lecce-0', 'Lecce-Trento-0')), ('a3473', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3474', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3475', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3476', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3477', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3478', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3479', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3480', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3481', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Rome-0', 'Rome-Trento-1')), ('a3482', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a3483', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3484', 'B', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-1', 'Palermo-Bologna-0', 'Bologna-Trento-0')), ('a3485', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-1')), ('a3486', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3487', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3488', 'J', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3489', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3490', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3491', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3492', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3493', 'B', 's1', ('Modena-Bergamo-1', 'Bergamo-Monza-0', 'Monza-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Lecce-0', 'Lecce-Trento-1')), ('a3494', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a3495', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3496', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3497', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3498', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3499', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3500', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3501', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3502', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3503', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3504', 'B', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3505', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Siena-0', 'Siena-Palermo-1', 'Palermo-Trento-0')), ('a3506', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3507', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3508', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a3509', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3510', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5', 'Trento-Padua-0')), ('a3511', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3512', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3513', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3514', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a3515', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3516', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3517', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3518', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a3519', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3520', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3521', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3522', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3523', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3524', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a3525', 'J', 's1', ('Monza-Torino-0', 'Torino-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3526', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3527', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3528', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3529', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3530', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3531', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3532', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3533', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3534', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3535', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-2')), ('a3536', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3537', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3538', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3539', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3540', 'E', 's1', ('Padua-Modena-0', 'Modena-Rome-0', 'Rome-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3541', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3542', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3543', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3544', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3545', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a3546', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3547', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3548', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a3549', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3550', 'J', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Lecce-0', 'Lecce-Udine-0', 'Udine-Trento-0')), ('a3551', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3552', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-6', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3553', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3554', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3555', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3556', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3557', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3558', 'J', 's1', ('Monza-Firenze-0', 'Firenze-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3559', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3560', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3561', 'B', 's1', ('Udine-Napoli-0', 'Napoli-Genova-1', 'Genova-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3562', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3563', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3564', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3565', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3566', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3567', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3568', 'J', 's1', ('Pisa-Modena-0', 'Modena-Lecce-0', 'Lecce-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Milano-0')), ('a3569', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3570', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3571', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3572', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3573', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3574', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3575', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3576', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3577', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3578', 'B', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3579', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3580', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3581', 'B', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3582', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3583', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3584', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3585', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3586', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3587', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3588', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3589', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3590', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3591', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3592', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3593', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3594', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3595', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-3', 'Trento-Udine-0', 'Udine-Milano-0')), ('a3596', 'B', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3597', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3598', 'B', 's1', ('Pisa-Modena-0', 'Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-0', 'Palermo-Trento-0')), ('a3599', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a3600', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3601', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3602', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3603', 'J', 's1', ('Verona-Modena-0', 'Modena-Napoli-0', 'Napoli-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Torino-0')), ('a3604', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3605', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3606', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a3607', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3608', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3609', 'B', 's1', ('Modena-Napoli-0', 'Napoli-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Pisa-0')), ('a3610', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a3611', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3612', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3613', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a3614', 'J', 's1', ('Monza-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Napoli-0')), ('a3615', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3616', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3617', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3618', 'B', 's1', ('Modena-Napoli-0', 'Napoli-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-1', 'Palermo-Lecce-0', 'Lecce-Trento-1')), ('a3619', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3620', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3621', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3622', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Genova-0', 'Genova-Trento-0', 'Trento-Udine-0', 'Udine-Verona-0')), ('a3623', 'J', 's1', ('Udine-Palermo-0', 'Palermo-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a3624', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3625', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3626', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3627', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3628', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3629', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3630', 'J', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3631', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3632', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3633', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3634', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3635', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3636', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Venezia-0', 'Venezia-Napoli-0', 'Napoli-Palermo-0', 'Palermo-Trento-0')), ('a3637', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3638', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3639', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3640', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Lecce-0', 'Lecce-Trento-1')), ('a3641', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-1')), ('a3642', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3643', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3644', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3645', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3646', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3647', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3648', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3649', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3650', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3651', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3652', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3653', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3654', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3655', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3656', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3657', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3658', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Rome-0', 'Rome-Palermo-1', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a3659', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3660', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3661', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-3')), ('a3662', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3663', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3664', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-1', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a3665', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Lecce-0')), ('a3666', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3667', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3668', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3669', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3670', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3671', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3672', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3673', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3674', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3675', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3676', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3677', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-6')), ('a3678', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3679', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3680', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3681', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3682', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3683', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3684', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3685', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3686', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3687', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3688', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3689', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3690', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3691', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3692', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3693', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3694', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3695', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3696', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3697', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3698', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3699', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a3700', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3701', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-1', 'Palermo-Trento-0')), ('a3702', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3703', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3704', 'J', 's1', ('Torino-Firenze-0', 'Firenze-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-3')), ('a3705', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3706', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0', 'Trento-Padua-0')), ('a3707', 'B', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-1', 'Palermo-Trento-0')), ('a3708', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3709', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0', 'Padua-Rome-0')), ('a3710', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3711', 'B', 's1', ('Monza-Modena-0', 'Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3712', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3713', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3714', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3715', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3716', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3717', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3718', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3719', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3720', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3721', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3722', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3723', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3724', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3725', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3726', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3727', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3728', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3729', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3730', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3731', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3732', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3733', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3734', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3735', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3736', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3737', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3738', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3739', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3740', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a3741', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3742', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3743', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3744', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3745', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3746', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a3747', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3748', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3749', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3750', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a3751', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3752', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3753', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3754', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3755', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3756', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3757', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3758', 'J', 's1', ('Modena-Genova-0', 'Genova-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3759', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a3760', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3761', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3762', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3763', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3764', 'J', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-3')), ('a3765', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3766', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3767', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3768', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3769', 'E', 's1', ('Rome-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3770', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3771', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3772', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a3773', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3774', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3775', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3776', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Monza-0', 'Monza-Napoli-0')), ('a3777', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3778', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3779', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3780', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3781', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3782', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-0')), ('a3783', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3784', 'B', 's1', ('Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a3785', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3786', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3787', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a3788', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3789', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3790', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3791', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a3792', 'B', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a3793', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3794', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3795', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3796', 'J', 's1', ('Genova-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Padua-0')), ('a3797', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3798', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Genova-0')), ('a3799', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3800', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3801', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4', 'Trento-Padua-0')), ('a3802', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a3803', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3804', 'B', 's1', ('Venezia-Modena-0', 'Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Siena-0', 'Siena-Trento-0')), ('a3805', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3806', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3807', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3808', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3809', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a3810', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3811', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3812', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3813', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3814', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3815', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3816', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3817', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3818', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3819', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a3820', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3821', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3822', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3823', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Padua-0')), ('a3824', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4')), ('a3825', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3826', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3827', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3828', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3829', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3830', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a3831', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3832', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3833', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3834', 'J', 's1', ('Torino-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Genova-0', 'Genova-Trento-0', 'Trento-Palermo-0')), ('a3835', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3836', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3837', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3838', 'J', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-3', 'Trento-Padua-0')), ('a3839', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3840', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3841', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3842', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3843', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3844', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0', 'Trento-Rome-0')), ('a3845', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Venezia-0', 'Venezia-Trento-0', 'Trento-Napoli-0', 'Napoli-Trento-0')), ('a3846', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3847', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Monza-0', 'Monza-Bolzano-0', 'Bolzano-Bologna-0')), ('a3848', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3849', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Firenze-1')), ('a3850', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3851', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3852', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3853', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a3854', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3855', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3856', 'B', 's1', ('Modena-Firenze-0', 'Firenze-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Torino-0', 'Torino-Trento-1', 'Trento-Napoli-0')), ('a3857', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Palermo-1', 'Palermo-Trento-0')), ('a3858', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3859', 'B', 's1', ('Bologna-Modena-0', 'Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3860', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3861', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3862', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3863', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3864', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3865', 'J', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0')), ('a3866', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3867', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3868', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3869', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3870', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3871', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3872', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3873', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3874', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3875', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3876', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a3877', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3878', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3879', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3880', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3881', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3882', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3883', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4')), ('a3884', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3885', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3886', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3887', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3888', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Siena-0', 'Siena-Napoli-0', 'Napoli-Milano-0')), ('a3889', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3890', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3891', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3892', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a3893', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3894', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3895', 'B', 's1', ('Pisa-Bolzano-0', 'Bolzano-Modena-0', 'Modena-Trento-0', 'Trento-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3896', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Firenze-1')), ('a3897', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a3898', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3899', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3900', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3901', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3902', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3903', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3904', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3905', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3906', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3907', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3908', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3909', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3910', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Palermo-0', 'Palermo-Trento-0', 'Trento-Venezia-0')), ('a3911', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3912', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3913', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3914', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Venezia-0', 'Venezia-Verona-0', 'Verona-Trento-0')), ('a3915', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3916', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3917', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a3918', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3919', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3920', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3921', 'B', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Monza-0', 'Monza-Palermo-1', 'Palermo-Trento-0')), ('a3922', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3')), ('a3923', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3924', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3925', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3926', 'J', 's1', ('Modena-Bologna-0', 'Bologna-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-3')), ('a3927', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3928', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3929', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3930', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3931', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3932', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3933', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3934', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3935', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a3936', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a3937', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a3938', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3939', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3940', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3941', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3942', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3943', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a3944', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3945', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3946', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3947', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3948', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3949', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3950', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3951', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3952', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3953', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a3954', 'B', 's1', ('Modena-Bologna-0', 'Bologna-Monza-0', 'Monza-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3955', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3956', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3957', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Genova-0', 'Genova-Trento-0')), ('a3958', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3959', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3960', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3961', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3962', 'B', 's1', ('Modena-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Palermo-0', 'Palermo-Firenze-0', 'Firenze-Trento-0')), ('a3963', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0', 'Trento-Lecce-0')), ('a3964', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3965', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3966', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3967', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3968', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a3969', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3970', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3971', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3972', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3973', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3974', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3975', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3976', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a3977', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3978', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3979', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a3980', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3981', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a3982', 'J', 's1', ('Pisa-Modena-0', 'Modena-Napoli-0', 'Napoli-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a3983', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a3984', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3985', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a3986', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3987', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3988', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a3989', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Milano-0')), ('a3990', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3991', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3992', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a3993', 'B', 's1', ('Modena-Siena-0', 'Siena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Siena-0')), ('a3994', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-2')), ('a3995', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a3996', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3')), ('a3997', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a3998', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a3999', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4000', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4001', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4002', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4003', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4004', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4005', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4006', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4007', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4008', 'B', 's1', ('Verona-Genova-0', 'Genova-Bolzano-0', 'Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4009', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4010', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4011', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4012', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4013', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4014', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4015', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Firenze-1', 'Firenze-Palermo-0', 'Palermo-Trento-3', 'Trento-Bologna-2')), ('a4016', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a4017', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4018', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4019', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4020', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Lecce-0')), ('a4021', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4022', 'J', 's1', ('Bolzano-Napoli-0', 'Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4023', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4024', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Firenze-0', 'Firenze-Trento-0')), ('a4025', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4026', 'B', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Napoli-0', 'Napoli-Palermo-1', 'Palermo-Trento-0')), ('a4027', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4028', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4029', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4030', 'E', 's1', ('Rome-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4031', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4032', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4033', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4034', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Trento-0')), ('a4035', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4036', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4037', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4038', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4039', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a4040', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4041', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4042', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4043', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4044', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4045', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4046', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4047', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a4048', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4049', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4050', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4051', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4052', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4053', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4054', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4055', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4056', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Udine-0', 'Udine-Milano-0', 'Milano-Monza-0', 'Monza-Trento-0')), ('a4057', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4058', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4059', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4060', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4061', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4062', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4063', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4064', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4065', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4066', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4067', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a4068', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a4069', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4070', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4071', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4072', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4073', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4074', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4075', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-1')), ('a4076', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4077', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4078', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4079', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4080', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4081', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4082', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4083', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4084', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4085', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4086', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-2')), ('a4087', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4088', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4089', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4090', 'J', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Pisa-0')), ('a4091', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4092', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4093', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4094', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4095', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4096', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4097', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4098', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4099', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4100', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4101', 'J', 's1', ('Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4102', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4103', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Milano-0', 'Milano-Trento-1')), ('a4104', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4105', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4106', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4107', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4108', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4109', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Siena-0', 'Siena-Trento-1')), ('a4110', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4111', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4112', 'J', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Venezia-0')), ('a4113', 'B', 's1', ('Milano-Lecce-0', 'Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4114', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4115', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4116', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4117', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0', 'Padua-Rome-0')), ('a4118', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4119', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4120', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4121', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4122', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4123', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4124', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a4125', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4126', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Padua-0', 'Padua-Trento-0')), ('a4127', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4128', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4129', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4130', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bologna-0', 'Bologna-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4131', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4132', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4133', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4134', 'J', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4135', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a4136', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4137', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4138', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4139', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4140', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4141', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4142', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4143', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4144', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4145', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4146', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4147', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4148', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a4149', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4150', 'B', 's1', ('Modena-Pisa-0', 'Pisa-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4151', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4152', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4153', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4154', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4155', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4156', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4157', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4158', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4159', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4160', 'B', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4161', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4162', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4163', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4164', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4165', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4166', 'B', 's1', ('Bologna-Torino-0', 'Torino-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4167', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4168', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4169', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4170', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4171', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Bologna-4')), ('a4172', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-1')), ('a4173', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4174', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4175', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4176', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4177', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4178', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4179', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4180', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4181', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-0')), ('a4182', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4183', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4184', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4185', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4186', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4187', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4188', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4189', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4190', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4191', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4192', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4193', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4194', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4195', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4196', 'J', 's1', ('Modena-Padua-0', 'Padua-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Trento-3')), ('a4197', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4198', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4199', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4200', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4201', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4202', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4203', 'J', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Trento-3')), ('a4204', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4205', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4206', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Rome-0')), ('a4207', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4208', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4209', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4210', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4211', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4212', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4213', 'J', 's1', ('Venezia-Bolzano-0', 'Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4214', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4215', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4216', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4217', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4218', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4219', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-3')), ('a4220', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4221', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4222', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4223', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4224', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4225', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4226', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4227', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4228', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4229', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4230', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4231', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4232', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4233', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4234', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4235', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4236', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4237', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-1')), ('a4238', 'J', 's1', ('Rome-Genova-1', 'Genova-Bolzano-0', 'Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4239', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a4240', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a4241', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4242', 'J', 's1', ('Modena-Monza-0', 'Monza-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Monza-0', 'Monza-Trento-1', 'Trento-Lecce-0')), ('a4243', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Torino-0')), ('a4244', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4245', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4246', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4247', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4248', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4249', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4250', 'B', 's1', ('Modena-Genova-0', 'Genova-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4251', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4252', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4253', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4254', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4255', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4256', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4257', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4258', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a4259', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4260', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4261', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4262', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4263', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4264', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4265', 'J', 's1', ('Bolzano-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4266', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a4267', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4268', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Monza-0', 'Monza-Palermo-1', 'Palermo-Trento-0')), ('a4269', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4270', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4271', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4272', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4273', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-1')), ('a4274', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4275', 'J', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-3')), ('a4276', 'B', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4277', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4278', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4279', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5', 'Trento-Padua-0')), ('a4280', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Lecce-0', 'Lecce-Trento-1', 'Trento-Venezia-0', 'Venezia-Firenze-0')), ('a4281', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4282', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-0')), ('a4283', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4284', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4285', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4286', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4287', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4288', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a4289', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4290', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4291', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4292', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Genova-0', 'Genova-Padua-0', 'Padua-Trento-0', 'Trento-Modena-0')), ('a4293', 'J', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-1', 'Palermo-Trento-0')), ('a4294', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-0')), ('a4295', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4296', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4297', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4298', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4299', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4300', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Milano-0', 'Milano-Palermo-0', 'Palermo-Trento-3')), ('a4301', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4302', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4303', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4304', 'E', 's1', ('Modena-Rome-0', 'Rome-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4305', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4306', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-1', 'Palermo-Trento-0')), ('a4307', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-0', 'Palermo-Trento-0')), ('a4308', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4309', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4310', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4311', 'B', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Bologna-3')), ('a4312', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a4313', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4314', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4315', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4316', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4317', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4318', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4319', 'B', 's1', ('Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Udine-0', 'Udine-Palermo-1', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a4320', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4321', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4322', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4323', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Genova-0', 'Genova-Palermo-0', 'Palermo-Trento-0')), ('a4324', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a4325', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4326', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4327', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4328', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Firenze-0', 'Firenze-Trento-0', 'Trento-Monza-0')), ('a4329', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a4330', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4331', 'B', 's1', ('Modena-Genova-0', 'Genova-Siena-0', 'Siena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-1', 'Palermo-Trento-0')), ('a4332', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-0', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a4333', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4334', 'J', 's1', ('Venezia-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Siena-0')), ('a4335', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4336', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4337', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4338', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4339', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4340', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4341', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4342', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4343', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4344', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a4345', 'J', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Bologna-0', 'Bologna-Trento-0')), ('a4346', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Firenze-3')), ('a4347', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4348', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4349', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4350', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4351', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4352', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4353', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4354', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4355', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4356', 'J', 's1', ('Modena-Genova-0', 'Genova-Pisa-0', 'Pisa-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Firenze-2')), ('a4357', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4358', 'B', 's1', ('Genova-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Siena-0', 'Siena-Trento-0', 'Trento-Monza-0')), ('a4359', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4360', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4361', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4362', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4363', 'J', 's1', ('Modena-Bolzano-0', 'Bolzano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Pisa-0')), ('a4364', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4365', 'B', 's1', ('Modena-Lecce-0', 'Lecce-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bolzano-0', 'Bolzano-Lecce-0', 'Lecce-Trento-1')), ('a4366', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4367', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4368', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4369', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4370', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a4371', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4372', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4373', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4374', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4375', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4376', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Rome-0', 'Rome-Trento-2')), ('a4377', 'B', 's1', ('Modena-Genova-0', 'Genova-Pisa-0', 'Pisa-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4378', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4379', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4380', 'J', 's1', ('Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4381', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a4382', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4383', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4384', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4385', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4386', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4387', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Pisa-0', 'Pisa-Modena-0', 'Modena-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4388', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4389', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4390', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4391', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4392', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4393', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a4394', 'B', 's1', ('Modena-Monza-0', 'Monza-Bergamo-1', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a4395', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4396', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4397', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4398', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4399', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a4400', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4401', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4402', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4403', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4404', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4405', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4406', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4407', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Venezia-0', 'Venezia-Trento-0', 'Trento-Padua-0')), ('a4408', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4409', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4410', 'J', 's1', ('Modena-Udine-0', 'Udine-Lecce-0', 'Lecce-Bergamo-1', 'Bergamo-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-3')), ('a4411', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4412', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4413', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4414', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4415', 'J', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-3')), ('a4416', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4417', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4418', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4419', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4420', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4421', 'B', 's1', ('Napoli-Venezia-0', 'Venezia-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Palermo-1', 'Palermo-Trento-0')), ('a4422', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4423', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4424', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Genova-0', 'Genova-Monza-0', 'Monza-Trento-0')), ('a4425', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4426', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Pisa-0', 'Pisa-Trento-1')), ('a4427', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4428', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Venezia-0', 'Venezia-Palermo-1', 'Palermo-Trento-0')), ('a4429', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4430', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4431', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4432', 'B', 's1', ('Modena-Pisa-0', 'Pisa-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Torino-0', 'Torino-Trento-1')), ('a4433', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4434', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4435', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4436', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Genova-0', 'Genova-Napoli-0', 'Napoli-Palermo-1', 'Palermo-Milano-0', 'Milano-Trento-1')), ('a4437', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4438', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4439', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4440', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4441', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4442', 'B', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4443', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4444', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4445', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4446', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4447', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4448', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4449', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4450', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4451', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4452', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a4453', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4454', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4455', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4456', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4457', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4458', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4459', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4460', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4461', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4462', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4463', 'B', 's1', ('Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Pisa-0', 'Pisa-Torino-0', 'Torino-Palermo-1', 'Palermo-Trento-0')), ('a4464', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4465', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4466', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4467', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4468', 'B', 's1', ('Bolzano-Siena-0', 'Siena-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Verona-0')), ('a4469', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Torino-0', 'Torino-Trento-1')), ('a4470', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4471', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4472', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4473', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4474', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4475', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4476', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4477', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4478', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4479', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4480', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4481', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4482', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Padua-0', 'Padua-Milano-0')), ('a4483', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4484', 'J', 's1', ('Siena-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a4485', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4486', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4487', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4488', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4489', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4490', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4491', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4492', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4493', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4494', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4495', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4496', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4497', 'B', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4498', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4499', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Milano-0', 'Milano-Torino-0', 'Torino-Trento-0')), ('a4500', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4501', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4502', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4503', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Palermo-1', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a4504', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4505', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Milano-0', 'Milano-Palermo-1', 'Palermo-Trento-0')), ('a4506', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4507', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4508', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Torino-0', 'Torino-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Trento-3', 'Trento-Lecce-0')), ('a4509', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4510', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4511', 'B', 's1', ('Firenze-Verona-1', 'Verona-Lecce-0', 'Lecce-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4512', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4513', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4514', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4515', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4516', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4517', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4518', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-2')), ('a4519', 'B', 's1', ('Monza-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4520', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a4521', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4522', 'B', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0', 'Trento-Bergamo-0')), ('a4523', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4524', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4525', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4526', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4527', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4528', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a4529', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Milano-0', 'Milano-Monza-0', 'Monza-Bologna-0', 'Bologna-Palermo-0', 'Palermo-Trento-3')), ('a4530', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4531', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4532', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4533', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4534', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4535', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4536', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4537', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4538', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a4539', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4540', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4541', 'J', 's1', ('Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-3')), ('a4542', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a4543', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4544', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-0', 'Palermo-Genova-0', 'Genova-Bolzano-0', 'Bolzano-Trento-0')), ('a4545', 'B', 's1', ('Modena-Pisa-0', 'Pisa-Bologna-0', 'Bologna-Napoli-0', 'Napoli-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4546', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4547', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4548', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Padua-0')), ('a4549', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4550', 'J', 's1', ('Bolzano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Milano-0')), ('a4551', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4552', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4553', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4554', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4555', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4556', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4557', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4558', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4559', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4560', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4561', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a4562', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4563', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4564', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4565', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4566', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4567', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4568', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4569', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4570', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4571', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4572', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4573', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4574', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4575', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4576', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4577', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4578', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4579', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4580', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Udine-0', 'Udine-Trento-0')), ('a4581', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4582', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4583', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4584', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4585', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4586', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4587', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4588', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4589', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4590', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4591', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4592', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4593', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4594', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4595', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4596', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4597', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4598', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4599', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4600', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4601', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4602', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4603', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4604', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4605', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a4606', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4607', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4608', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4609', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4610', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4611', 'B', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Pisa-0', 'Pisa-Palermo-0', 'Palermo-Trento-0')), ('a4612', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4613', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4614', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4615', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4616', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4617', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4618', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0', 'Trento-Genova-2')), ('a4619', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4620', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4621', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4622', 'J', 's1', ('Monza-Modena-0', 'Modena-Venezia-0', 'Venezia-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a4623', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4624', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4625', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-1', 'Trento-Rome-0')), ('a4626', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4627', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4628', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4629', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4630', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4631', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4632', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4633', 'J', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4634', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4635', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4636', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4637', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4638', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4639', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4640', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4641', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a4642', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4643', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4644', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4645', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4646', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4647', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4648', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4649', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4650', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4651', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-6')), ('a4652', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4653', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4654', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4655', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Napoli-0', 'Napoli-Verona-0', 'Verona-Bolzano-0', 'Bolzano-Trento-0')), ('a4656', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4657', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4658', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Venezia-0')), ('a4659', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4660', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4661', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4662', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4663', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4664', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4665', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4666', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4667', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4668', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4669', 'B', 's1', ('Venezia-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4670', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-1')), ('a4671', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4672', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4673', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4674', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4675', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Padua-0', 'Padua-Trento-2', 'Trento-Genova-0')), ('a4676', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0', 'Trento-Pisa-0')), ('a4677', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4678', 'J', 's1', ('Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4679', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Venezia-0', 'Venezia-Firenze-0', 'Firenze-Siena-0', 'Siena-Trento-1')), ('a4680', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4681', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Torino-0', 'Torino-Genova-0', 'Genova-Palermo-1', 'Palermo-Venezia-0', 'Venezia-Trento-0')), ('a4682', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4683', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4684', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4685', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4686', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4687', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4688', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4689', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0')), ('a4690', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4691', 'J', 's1', ('Napoli-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4692', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4693', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4694', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Torino-0')), ('a4695', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4696', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4697', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4698', 'J', 's1', ('Modena-Siena-0', 'Siena-Genova-0', 'Genova-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Monza-0')), ('a4699', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4700', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4701', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4702', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4703', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4704', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4705', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4706', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4707', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4708', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Napoli-0', 'Napoli-Trento-0', 'Trento-Siena-0', 'Siena-Monza-0')), ('a4709', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Bologna-0', 'Bologna-Trento-0', 'Trento-Napoli-0', 'Napoli-Lecce-0')), ('a4710', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4711', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-0', 'Palermo-Trento-0')), ('a4712', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4713', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4714', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4715', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4716', 'E', 's1', ('Padua-Modena-0', 'Modena-Rome-0', 'Rome-Bergamo-4', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4717', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4718', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4719', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4720', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4721', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4722', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4723', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4724', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4725', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4726', 'J', 's1', ('Udine-Genova-5', 'Genova-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4727', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a4728', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4729', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Firenze-0', 'Firenze-Palermo-1', 'Palermo-Trento-0')), ('a4730', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4731', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4732', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4733', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4734', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4735', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4736', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4737', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4738', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4739', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Torino-0', 'Torino-Siena-0', 'Siena-Trento-0', 'Trento-Modena-0')), ('a4740', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4741', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4742', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4743', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4744', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4745', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a4746', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4747', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4748', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4749', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4750', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4751', 'J', 's1', ('Milano-Lecce-0', 'Lecce-Padua-0', 'Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4752', 'J', 's1', ('Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0')), ('a4753', 'B', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Monza-0', 'Monza-Trento-0')), ('a4754', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4755', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4756', 'J', 's1', ('Modena-Bologna-0', 'Bologna-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3', 'Trento-Genova-0')), ('a4757', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-5')), ('a4758', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4759', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4760', 'J', 's1', ('Udine-Modena-0', 'Modena-Venezia-0', 'Venezia-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4761', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4762', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4763', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4764', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Torino-0', 'Torino-Trento-0', 'Trento-Napoli-0')), ('a4765', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4766', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4767', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4768', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4769', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4770', 'E', 's1', ('Padua-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-4')), ('a4771', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4772', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4773', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4774', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4775', 'B', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4776', 'E', 's1', ('Modena-Padua-0', 'Padua-Rome-0', 'Rome-Bergamo-6', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4777', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4778', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4779', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4780', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4781', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4782', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a4783', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4784', 'J', 's1', ('Pisa-Modena-0', 'Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4785', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4786', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4787', 'B', 's1', ('Modena-Trento-0', 'Trento-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Lecce-0', 'Lecce-Palermo-0', 'Palermo-Trento-0')), ('a4788', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4789', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4790', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4791', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4792', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4793', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4794', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4795', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4796', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4797', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4798', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4799', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4800', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4801', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Milano-0')), ('a4802', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4803', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4804', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Monza-0', 'Monza-Palermo-1', 'Palermo-Trento-0')), ('a4805', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4806', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4807', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4808', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4809', 'B', 's1', ('Venezia-Modena-0', 'Modena-Genova-0', 'Genova-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Genova-2')), ('a4810', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4811', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4812', 'J', 's1', ('Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4813', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4814', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4815', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6', 'Trento-Padua-0', 'Padua-Rome-0')), ('a4816', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4817', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4818', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4819', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4820', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4821', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4822', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4823', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4824', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4825', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Padua-0')), ('a4826', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4827', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4828', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4829', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3')), ('a4830', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4831', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4832', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4833', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4834', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4835', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4836', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4837', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a4838', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4839', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4840', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4841', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-1')), ('a4842', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4843', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4844', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4845', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4846', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4847', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a4848', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4849', 'B', 's1', ('Firenze-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4850', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4851', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4852', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4853', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4854', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4855', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4856', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4857', 'J', 's1', ('Modena-Napoli-0', 'Napoli-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Rome-0', 'Rome-Genova-0')), ('a4858', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4859', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4860', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Siena-0', 'Siena-Trento-0', 'Trento-Torino-0')), ('a4861', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4862', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-5')), ('a4863', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4864', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4865', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4866', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4867', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4868', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4869', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4870', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4871', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4872', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4873', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4874', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4875', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4876', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0', 'Trento-Bologna-2', 'Bologna-Torino-0', 'Torino-Bergamo-1')), ('a4877', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4878', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4879', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-0')), ('a4880', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4881', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4882', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4883', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-6')), ('a4884', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4885', 'E', 's1', ('Modena-Padua-0', 'Padua-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Rome-0', 'Rome-Trento-0')), ('a4886', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4887', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Milano-0', 'Milano-Trento-1', 'Trento-Milano-0', 'Milano-Napoli-0')), ('a4888', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-5')), ('a4889', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4890', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4891', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4892', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4893', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4894', 'B', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Udine-0', 'Udine-Trento-0', 'Trento-Padua-0')), ('a4895', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4896', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4897', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3')), ('a4898', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-3', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a4899', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4900', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4901', 'B', 's1', ('Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4902', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4903', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4904', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4905', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4906', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-0')), ('a4907', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4908', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4909', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4910', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4911', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Bolzano-0', 'Bolzano-Monza-0', 'Monza-Trento-0', 'Trento-Bergamo-0')), ('a4912', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4913', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4914', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4915', 'B', 's1', ('Modena-Udine-0', 'Udine-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4916', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4917', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4918', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4919', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4920', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4921', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4922', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Torino-0')), ('a4923', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4924', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4925', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4926', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4927', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4928', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4929', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4930', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4931', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4932', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4933', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4934', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Verona-0', 'Verona-Trento-0')), ('a4935', 'B', 's1', ('Monza-Bolzano-0', 'Bolzano-Modena-0', 'Modena-Milano-0', 'Milano-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4936', 'B', 's1', ('Bologna-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4937', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4938', 'E', 's1', ('Modena-Bergamo-3', 'Bergamo-Rome-0', 'Rome-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-0')), ('a4939', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4940', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-3', 'Trento-Pisa-0')), ('a4941', 'A', 's1', ('Modena-Bergamo-3', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4942', 'E', 's1', ('Rome-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Padua-0', 'Padua-Palermo-0', 'Palermo-Trento-1')), ('a4943', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4944', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4945', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4946', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4947', 'A', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4948', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4949', 'B', 's1', ('Lecce-Milano-0', 'Milano-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4950', 'D', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4951', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4952', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4953', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4954', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4955', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4956', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4957', 'E', 's1', ('Modena-Rome-0', 'Rome-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4958', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4959', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4960', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4961', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4962', 'E', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4963', 'B', 's1', ('Padua-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Bologna-0', 'Bologna-Trento-0', 'Trento-Milano-0')), ('a4964', 'J', 's1', ('Torino-Modena-0', 'Modena-Bergamo-1', 'Bergamo-Bolzano-0', 'Bolzano-Palermo-1', 'Palermo-Trento-0', 'Trento-Modena-0')), ('a4965', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-3')), ('a4966', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4967', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-0')), ('a4968', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4969', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0', 'Trento-Palermo-0', 'Palermo-Trento-0', 'Trento-Firenze-5', 'Firenze-Lecce-0')), ('a4970', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4971', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Verona-0', 'Verona-Palermo-0', 'Palermo-Trento-1')), ('a4972', 'J', 's1', ('Modena-Bergamo-1', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4973', 'G', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-1', 'Palermo-Trento-4')), ('a4974', 'C', 's1', ('Verona-Modena-0', 'Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4975', 'C', 's1', ('Modena-Verona-0', 'Verona-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4976', 'C', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1', 'Trento-Verona-0')), ('a4977', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-4')), ('a4978', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4979', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4980', 'D', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4981', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-1')), ('a4982', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4983', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-3', 'Trento-Napoli-0')), ('a4984', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4985', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4986', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4987', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Venezia-0', 'Venezia-Palermo-0', 'Palermo-Trento-0', 'Trento-Padua-0')), ('a4988', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-1')), ('a4989', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Trento-0')), ('a4990', 'H', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4991', 'A', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4992', 'G', 's1', ('Modena-Bergamo-2', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4993', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-2', 'Palermo-Trento-2')), ('a4994', 'E', 's1', ('Modena-Bergamo-0', 'Bergamo-Rome-0', 'Rome-Palermo-0', 'Palermo-Trento-1', 'Trento-Padua-0')), ('a4995', 'B', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4996', 'F', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0')), ('a4997', 'I', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-2')), ('a4998', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Napoli-0', 'Napoli-Monza-0', 'Monza-Bologna-0', 'Bologna-Palermo-1', 'Palermo-Trento-0')), ('a4999', 'J', 's1', ('Monza-Modena-0', 'Modena-Torino-0', 'Torino-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0')), ('a5000', 'J', 's1', ('Modena-Bergamo-0', 'Bergamo-Palermo-3', 'Palermo-Trento-0', 'Trento-Udine-0')), ('a5001', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a5002', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5003', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5004', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5005', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5006', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5007', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5008', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5009', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a5010', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5011', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5012', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5013', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5014', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5015', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5016', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5017', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5018', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5019', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a5020', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5021', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5022', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5023', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5024', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5025', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5026', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5027', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5028', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5029', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5030', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5031', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5032', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5033', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5034', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5035', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5036', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5037', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5038', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5039', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5040', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5041', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5042', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5043', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5044', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5045', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5046', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5047', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5048', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5049', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5050', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5051', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5052', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5053', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5054', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5055', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5056', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5057', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5058', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5059', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5060', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-5')), ('a5061', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5062', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5063', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5064', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5065', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5066', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5067', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5068', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5069', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5070', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5071', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5072', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5073', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5074', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5075', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5076', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5077', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5078', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a5079', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5080', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5081', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5082', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5083', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5084', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a5085', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5086', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5087', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5088', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5089', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5090', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5091', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5092', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5093', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Rome-0', 'Rome-Verona-0')), ('a5094', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5095', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5096', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5097', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5098', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5099', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5100', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5101', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5102', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5103', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5104', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5105', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5106', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5107', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5108', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5109', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5110', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5111', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5112', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5113', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5114', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5115', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5116', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5117', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5118', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5119', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5120', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5121', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5122', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5123', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5124', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5125', 'E', 's2', ('Napoli-Rome-0', 'Rome-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5126', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5127', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5128', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5129', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5130', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5131', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5132', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5133', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5134', 'F', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5135', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5136', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5137', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5138', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5139', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5140', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5141', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5142', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5143', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5144', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5145', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5146', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5147', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5148', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5149', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5150', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5151', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5152', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5153', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5154', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5155', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5156', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5157', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5158', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a5159', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5160', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5161', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5162', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5163', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5164', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5165', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5166', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5167', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5168', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5169', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5170', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5171', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5172', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5173', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5174', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5175', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5176', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5177', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5178', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Padua-0')), ('a5179', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5180', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a5181', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5182', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5183', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5184', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5185', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5186', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5187', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a5188', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5189', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5190', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5191', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5192', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5193', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5194', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5195', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5196', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5197', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5198', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5199', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5200', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5201', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5202', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5203', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5204', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5205', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5206', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5207', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5208', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5209', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5210', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5211', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5212', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5213', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a5214', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5215', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5216', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a5217', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5218', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5219', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5220', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5221', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5222', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5223', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5224', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a5225', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5226', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-5')), ('a5227', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5228', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5229', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5230', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a5231', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5232', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a5233', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a5234', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5235', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5236', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5237', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5238', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5239', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5240', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5241', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5242', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5243', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5244', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5245', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a5246', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5247', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5248', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5249', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5250', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5251', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5252', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5253', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5254', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5255', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5256', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5257', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5258', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5259', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5260', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a5261', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5262', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5263', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5264', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5265', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5266', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5267', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5268', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5269', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5270', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5271', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5272', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5273', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5274', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5275', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5276', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-8', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5277', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5278', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5279', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5280', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5281', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5282', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5283', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5284', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5285', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5286', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5287', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5288', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5289', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5290', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5291', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5292', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5293', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5294', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5295', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5296', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5297', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5298', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5299', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a5300', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5301', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5302', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5303', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5304', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5305', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5306', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5307', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5308', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5309', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5310', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a5311', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5312', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5313', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5314', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5315', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5316', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5317', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5318', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5319', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5320', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5321', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5322', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5323', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5324', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5325', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5326', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a5327', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5328', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5329', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2', 'Verona-Rome-0')), ('a5330', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5331', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5332', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5333', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5334', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5335', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5336', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5337', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5338', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5339', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a5340', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5341', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5342', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a5343', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5344', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5345', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5346', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a5347', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5348', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5349', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5350', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5351', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5352', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5353', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a5354', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5355', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5356', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5357', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5358', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5359', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5360', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5361', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5362', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5363', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5364', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5365', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5366', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5367', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5368', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5369', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5370', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5371', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5372', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5373', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5374', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5375', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5376', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5377', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5378', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5379', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5380', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a5381', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5382', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5383', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5384', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5385', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5386', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5387', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5388', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5389', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5390', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5391', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5392', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5393', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5394', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5395', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5396', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5397', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-3')), ('a5398', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5399', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5400', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5401', 'E', 's2', ('Napoli-Rome-0', 'Rome-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5402', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5403', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5404', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5405', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5406', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5407', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5408', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-5')), ('a5409', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5410', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5411', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5412', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5413', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5414', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5415', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5416', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5417', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5418', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5419', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5420', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5421', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5422', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5423', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5424', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5425', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5426', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-7', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5427', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5428', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5429', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Rome-0', 'Rome-Verona-0')), ('a5430', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5431', 'E', 's2', ('Napoli-Rome-0', 'Rome-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5432', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5433', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5434', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5435', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5436', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5437', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5438', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Rome-0')), ('a5439', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5440', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5441', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5442', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5443', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5444', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5445', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5446', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5447', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0', 'Verona-Rome-0')), ('a5448', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5449', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5450', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5451', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5452', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5453', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5454', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5455', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a5456', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5457', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5458', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5459', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5460', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5461', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Rome-0', 'Rome-Verona-0')), ('a5462', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5463', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5464', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a5465', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5466', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5467', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5468', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5469', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5470', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5471', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5472', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5473', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5474', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5475', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5476', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5477', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5478', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a5479', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5480', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5481', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5482', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5483', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a5484', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-5')), ('a5485', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5486', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5487', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5488', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a5489', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a5490', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5491', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5492', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5493', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5494', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5495', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5496', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5497', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5498', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5499', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5500', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5501', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5502', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5503', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5504', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5505', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5506', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5507', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5508', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a5509', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5510', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5511', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5512', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5513', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a5514', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5515', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5516', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5517', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5518', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5519', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5520', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5521', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5522', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5523', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5524', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5525', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5526', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5527', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5528', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5529', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5530', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5531', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5532', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5533', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5534', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5535', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5536', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5537', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5538', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5539', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5540', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5541', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5542', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5543', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5544', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5545', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5546', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5547', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5548', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5549', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5550', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5551', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5552', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5553', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5554', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5555', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5556', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5557', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5558', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5559', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5560', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5561', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5562', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5563', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5564', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5565', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5566', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5567', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5568', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5569', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5570', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a5571', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5572', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5573', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5574', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5575', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5576', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5577', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5578', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5579', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5580', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5581', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5582', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5583', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5584', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5585', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5586', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5587', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5588', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5589', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5590', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5591', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5592', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5593', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5594', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5595', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5596', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5597', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5598', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5599', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5600', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5601', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5602', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5603', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5604', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5605', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5606', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a5607', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5608', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5609', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5610', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5611', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5612', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5613', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5614', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5615', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5616', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5617', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5618', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5619', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5620', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5621', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5622', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5623', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5624', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5625', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5626', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5627', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5628', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5629', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5630', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5631', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5632', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5633', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5634', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5635', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5636', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5637', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5638', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5639', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5640', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5641', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5642', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5643', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5644', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5645', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-3')), ('a5646', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5647', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5648', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5649', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5650', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5651', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5652', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5653', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5654', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5655', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5656', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5657', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5658', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a5659', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5660', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5661', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5662', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5663', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5664', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5665', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5666', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5667', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a5668', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5669', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5670', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5671', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5672', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5673', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5674', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5675', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5676', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5677', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5678', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5679', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5680', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5681', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a5682', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5683', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5684', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a5685', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5686', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5687', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5688', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-3')), ('a5689', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5690', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5691', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5692', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5693', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5694', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5695', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5696', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5697', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5698', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a5699', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5700', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5701', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5702', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5703', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5704', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5705', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5706', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5707', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5708', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5709', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5710', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5711', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5712', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5713', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5714', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5715', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5716', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5717', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5718', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a5719', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5720', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5721', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5722', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5723', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5724', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5725', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5726', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5727', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5728', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5729', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5730', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5731', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a5732', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5733', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5734', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5735', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5736', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5737', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5738', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5739', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5740', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a5741', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5742', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5743', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5744', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5745', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a5746', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5747', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5748', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5749', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5750', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5751', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5752', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5753', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5754', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5755', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5756', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5757', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5758', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a5759', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5760', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5761', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5762', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5763', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Padua-0')), ('a5764', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5765', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5766', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5767', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5768', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5769', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5770', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5771', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5772', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a5773', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5774', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a5775', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5776', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5777', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5778', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5779', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5780', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5781', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5782', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5783', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5784', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5785', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a5786', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5787', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5788', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a5789', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5790', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5791', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5792', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5793', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5794', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5795', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5796', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5797', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5798', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5799', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5800', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5801', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5802', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5803', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5804', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5805', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5806', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5807', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5808', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5809', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5810', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5811', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a5812', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5813', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5814', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5815', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5816', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5817', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5818', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5819', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5820', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5821', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5822', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5823', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5824', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5825', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5826', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5827', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5828', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5829', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5830', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5831', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5832', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5833', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5834', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5835', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5836', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5837', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5838', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5839', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5840', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5841', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5842', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5843', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5844', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5845', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5846', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5847', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5848', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5849', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5850', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5851', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5852', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5853', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5854', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a5855', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5856', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5857', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5858', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5859', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5860', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5861', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5862', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5863', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5864', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5865', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5866', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5867', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5868', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5869', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5870', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5871', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5872', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5873', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5874', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5875', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5876', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5877', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5878', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5879', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5880', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5881', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5882', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5883', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5884', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5885', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5886', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5887', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5888', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5889', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a5890', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Rome-0')), ('a5891', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5892', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a5893', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5894', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5895', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5896', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5897', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5898', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5899', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5900', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5901', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5902', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5903', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5904', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5905', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5906', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5907', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5908', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5909', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5910', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5911', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5912', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5913', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5914', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5915', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5916', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5917', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5918', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5919', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5920', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5921', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5922', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5923', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5924', 'F', 's2', ('Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5925', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5926', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5927', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5928', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5929', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5930', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5931', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5932', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5933', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5934', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5935', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5936', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5937', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5938', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5939', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5940', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5941', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5942', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a5943', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5944', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5945', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5946', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5947', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5948', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5949', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0', 'Rome-Padua-0')), ('a5950', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5951', 'E', 's2', ('Napoli-Rome-0', 'Rome-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5952', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5953', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5954', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5955', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5956', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5957', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5958', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5959', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5960', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5961', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5962', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5963', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5964', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5965', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5966', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5967', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-5', 'Verona-Rome-0')), ('a5968', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5969', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a5970', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5971', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5972', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a5973', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5974', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a5975', 'E', 's2', ('Napoli-Udine-3', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a5976', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5977', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a5978', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5979', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5980', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5981', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5982', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5983', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5984', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5985', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a5986', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5987', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5988', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a5989', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a5990', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a5991', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5992', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5993', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a5994', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5995', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5996', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a5997', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a5998', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a5999', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6000', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6001', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6002', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6003', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6004', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6005', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6006', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6007', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6008', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6009', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-3', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6010', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6011', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6012', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a6013', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a6014', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6015', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6016', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6017', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6018', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6019', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6020', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6021', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6022', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6023', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6024', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6025', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6026', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6027', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6028', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6029', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6030', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6031', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6032', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6033', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6034', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6035', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6036', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6037', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6038', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6039', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6040', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6041', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6042', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6043', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6044', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a6045', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6046', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6047', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6048', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6049', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6050', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6051', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2', 'Verona-Rome-0')), ('a6052', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a6053', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6054', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6055', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a6056', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6057', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6058', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6059', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6060', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6061', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6062', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6063', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6064', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6065', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6066', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6067', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6068', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6069', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6070', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6071', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6072', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6073', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6074', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6075', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6076', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6077', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6078', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6079', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6080', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6081', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6082', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6083', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6084', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6085', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6086', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6087', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6088', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6089', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6090', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6091', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6092', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6093', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6094', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6095', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6096', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6097', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6098', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6099', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a6100', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6101', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6102', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6103', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6104', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6105', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6106', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6107', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6108', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6109', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6110', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6111', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6112', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6113', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6114', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6115', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6116', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6117', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6118', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6119', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6120', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6121', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6122', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6123', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6124', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6125', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6126', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6127', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6128', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6129', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6130', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6131', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6132', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6133', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6134', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6135', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6136', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6137', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6138', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a6139', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6140', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6141', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6142', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6143', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6144', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6145', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6146', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6147', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6148', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6149', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6150', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6151', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6152', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6153', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6154', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6155', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6156', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6157', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6158', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6159', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6160', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6161', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6162', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6163', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-3', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6164', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6165', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6166', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6167', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6168', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6169', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6170', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6171', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6172', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6173', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6174', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6175', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6176', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6177', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6178', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6179', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6180', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6181', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6182', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6183', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6184', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6185', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6186', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6187', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6188', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6189', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6190', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6191', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6192', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6193', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6194', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6195', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6196', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6197', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6198', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6199', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6200', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6201', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6202', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6203', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6204', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6205', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6206', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6207', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6208', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6209', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6210', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6211', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6212', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6213', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6214', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6215', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6216', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6217', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6218', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6219', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6220', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6221', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6222', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6223', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-5')), ('a6224', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6225', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6226', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6227', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6228', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6229', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6230', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6231', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6232', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6233', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6234', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6235', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6236', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6237', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6238', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6239', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6240', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6241', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-2')), ('a6242', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6243', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6244', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6245', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6246', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6247', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6248', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6249', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6250', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6251', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6252', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6253', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6254', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6255', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6256', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6257', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6258', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6259', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6260', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6261', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6262', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6263', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6264', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6265', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a6266', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6267', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6268', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a6269', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6270', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6271', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6272', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6273', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6274', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6275', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6276', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6277', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6278', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6279', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6280', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6281', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6282', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6283', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6284', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6285', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6286', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a6287', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6288', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6289', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6290', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a6291', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6292', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6293', 'E', 's2', ('Napoli-Rome-0', 'Rome-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6294', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6295', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6296', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6297', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6298', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6299', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6300', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6301', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6302', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6303', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6304', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6305', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6306', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6307', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6308', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6309', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6310', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6311', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6312', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6313', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0', 'Padua-Rome-0')), ('a6314', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6315', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6316', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6317', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6318', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6319', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6320', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6321', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6322', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6323', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6324', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6325', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6326', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6327', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6328', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6329', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6330', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6331', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6332', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a6333', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6334', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6335', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6336', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6337', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6338', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6339', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6340', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6341', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6342', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6343', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2', 'Verona-Padua-0')), ('a6344', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6345', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6346', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6347', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-3')), ('a6348', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6349', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6350', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6351', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6352', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6353', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6354', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a6355', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6356', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6357', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6358', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6359', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6360', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6361', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6362', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6363', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-3')), ('a6364', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6365', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6366', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6367', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6368', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6369', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6370', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6371', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6372', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6373', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6374', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6375', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6376', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6377', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6378', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6379', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6380', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6381', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a6382', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6383', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6384', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6385', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6386', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6387', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6388', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6389', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6390', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6391', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6392', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a6393', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6394', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6395', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6396', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6397', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6398', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6399', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6400', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6401', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6402', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6403', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6404', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6405', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6406', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6407', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-2')), ('a6408', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6409', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6410', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6411', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6412', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6413', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6414', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6415', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6416', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6417', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6418', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a6419', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6420', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6421', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a6422', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6423', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6424', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6425', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6426', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6427', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6428', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6429', 'E', 's2', ('Napoli-Padua-0', 'Padua-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6430', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6431', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6432', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6433', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6434', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6435', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6436', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6437', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6438', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6439', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6440', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6441', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6442', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6443', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6444', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6445', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6446', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a6447', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6448', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6449', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6450', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6451', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6452', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6453', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6454', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6455', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6456', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6457', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6458', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6459', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6460', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6461', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6462', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6463', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6464', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6465', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6466', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6467', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6468', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6469', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6470', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6471', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6472', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6473', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6474', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6475', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6476', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6477', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6478', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6479', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6480', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6481', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6482', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6483', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6484', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6485', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6486', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6487', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6488', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6489', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6490', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a6491', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6492', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6493', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6494', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6495', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6496', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6497', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6498', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6499', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6500', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6501', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6502', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a6503', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6504', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6505', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6506', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6507', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6508', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6509', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6510', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6511', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6512', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6513', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6514', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6515', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6516', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6517', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6518', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6519', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6520', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6521', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6522', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6523', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6524', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6525', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6526', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6527', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6528', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6529', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-5')), ('a6530', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6531', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6532', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6533', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6534', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6535', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6536', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6537', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6538', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6539', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6540', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6541', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6542', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6543', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6544', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6545', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6546', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6547', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6548', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6549', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6550', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6551', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6552', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6553', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6554', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6555', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6556', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6557', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6558', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6559', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6560', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6561', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6562', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6563', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6564', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a6565', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6566', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6567', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6568', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6569', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6570', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6571', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6572', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6573', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6574', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6575', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6576', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6577', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6578', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6579', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6580', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6581', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6582', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6583', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6584', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6585', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6586', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2', 'Verona-Rome-0')), ('a6587', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6588', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6589', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6590', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6591', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6592', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6593', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6594', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6595', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6596', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6597', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6598', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6599', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6600', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6601', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6602', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6603', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6604', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6605', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6606', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6607', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6608', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6609', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6610', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6611', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6612', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6613', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6614', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6615', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6616', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6617', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6618', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6619', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6620', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6621', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a6622', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Padua-0', 'Padua-Verona-0')), ('a6623', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6624', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a6625', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6626', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6627', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6628', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6629', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6630', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6631', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6632', 'F', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6633', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6634', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6635', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6636', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6637', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6638', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6639', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6640', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6641', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6642', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6643', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6644', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6645', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6646', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6647', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6648', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6649', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6650', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6651', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6652', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6653', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6654', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6655', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6656', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6657', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6658', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6659', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6660', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6661', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6662', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6663', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6664', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6665', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6666', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a6667', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a6668', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6669', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6670', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6671', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6672', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6673', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6674', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6675', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6676', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6677', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6678', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6679', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6680', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6681', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6682', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6683', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6684', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6685', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6686', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6687', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6688', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6689', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6690', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6691', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6692', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6693', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a6694', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6695', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6696', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6697', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6698', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6699', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6700', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6701', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6702', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6703', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6704', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a6705', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6706', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6707', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6708', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a6709', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a6710', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6711', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6712', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6713', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6714', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6715', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6716', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6717', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6718', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6719', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6720', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6721', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6722', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6723', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a6724', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6725', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6726', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6727', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6728', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6729', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6730', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6731', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6732', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6733', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6734', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6735', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6736', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6737', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6738', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6739', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6740', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6741', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6742', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6743', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6744', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6745', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-6', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6746', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6747', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-6', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6748', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6749', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6750', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6751', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6752', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6753', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6754', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a6755', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6756', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6757', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6758', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6759', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6760', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6761', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6762', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6763', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-3')), ('a6764', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6765', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6766', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6767', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6768', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6769', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6770', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6771', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6772', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6773', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a6774', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a6775', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6776', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6777', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6778', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6779', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6780', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6781', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6782', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6783', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6784', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6785', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6786', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6787', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6788', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6789', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6790', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6791', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6792', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6793', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6794', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6795', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6796', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6797', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6798', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6799', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6800', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6801', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6802', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6803', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6804', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6805', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a6806', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6807', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6808', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6809', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6810', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a6811', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a6812', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6813', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6814', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6815', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6816', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6817', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6818', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6819', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6820', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6821', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6822', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6823', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6824', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6825', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6826', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6827', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6828', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6829', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6830', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6831', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6832', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6833', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a6834', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6835', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6836', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6837', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6838', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6839', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6840', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a6841', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6842', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6843', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6844', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6845', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6846', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6847', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6848', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6849', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6850', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6851', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6852', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6853', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6854', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6855', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6856', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6857', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6858', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6859', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6860', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6861', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6862', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a6863', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6864', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6865', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6866', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6867', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6868', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6869', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6870', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6871', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6872', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6873', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a6874', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6875', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a6876', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6877', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6878', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6879', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6880', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6881', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6882', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6883', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6884', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6885', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6886', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6887', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6888', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6889', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6890', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a6891', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6892', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6893', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6894', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a6895', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6896', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6897', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6898', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6899', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-3')), ('a6900', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6901', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6902', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6903', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a6904', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6905', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a6906', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6907', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6908', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6909', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6910', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6911', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6912', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6913', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6914', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6915', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6916', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6917', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6918', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6919', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6920', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6921', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a6922', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6923', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6924', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6925', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6926', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6927', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6928', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6929', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6930', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6931', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6932', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6933', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6934', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6935', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6936', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6937', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6938', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6939', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6940', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6941', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6942', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6943', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6944', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a6945', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6946', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a6947', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a6948', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6949', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6950', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6951', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6952', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a6953', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6954', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a6955', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a6956', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6957', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-2')), ('a6958', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6959', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6960', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6961', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6962', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6963', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6964', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6965', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6966', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6967', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6968', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6969', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6970', 'E', 's2', ('Napoli-Rome-0', 'Rome-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6971', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6972', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6973', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6974', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6975', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6976', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6977', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6978', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a6979', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a6980', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a6981', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6982', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6983', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a6984', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6985', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6986', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6987', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6988', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6989', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6990', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6991', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6992', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6993', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6994', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6995', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a6996', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a6997', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a6998', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a6999', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7000', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7001', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a7002', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7003', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7004', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a7005', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7006', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7007', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a7008', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7009', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7010', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7011', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7012', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7013', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7014', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7015', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7016', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7017', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7018', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7019', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7020', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7021', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7022', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7023', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7024', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7025', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7026', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7027', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7028', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7029', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7030', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7031', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7032', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7033', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7034', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7035', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7036', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7037', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7038', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7039', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7040', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7041', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7042', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7043', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7044', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7045', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7046', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7047', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7048', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a7049', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7050', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7051', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7052', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7053', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7054', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7055', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7056', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7057', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7058', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7059', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7060', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7061', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7062', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7063', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7064', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7065', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7066', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7067', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7068', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7069', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7070', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7071', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7072', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7073', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7074', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7075', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7076', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7077', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7078', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7079', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7080', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7081', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7082', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7083', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7084', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7085', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7086', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7087', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7088', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7089', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7090', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7091', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7092', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7093', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7094', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7095', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7096', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7097', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7098', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7099', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7100', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7101', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7102', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7103', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7104', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7105', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7106', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7107', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7108', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7109', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7110', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7111', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7112', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7113', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7114', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7115', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7116', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7117', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7118', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7119', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7120', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7121', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7122', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7123', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7124', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7125', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a7126', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7127', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7128', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7129', 'F', 's2', ('Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7130', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7131', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a7132', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7133', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7134', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7135', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7136', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7137', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7138', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7139', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7140', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7141', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7142', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7143', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7144', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7145', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a7146', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7147', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7148', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7149', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7150', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7151', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7152', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7153', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7154', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7155', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7156', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7157', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7158', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7159', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7160', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7161', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7162', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7163', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7164', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7165', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7166', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7167', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7168', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7169', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7170', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7171', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7172', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7173', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7174', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7175', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7176', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7177', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7178', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7179', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7180', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7181', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7182', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7183', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7184', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-3')), ('a7185', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7186', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7187', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7188', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7189', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7190', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7191', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7192', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7193', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7194', 'F', 's2', ('Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7195', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7196', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7197', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7198', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7199', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7200', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7201', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7202', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7203', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7204', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7205', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7206', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7207', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7208', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7209', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7210', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7211', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a7212', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7213', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7214', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7215', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a7216', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7217', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7218', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7219', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7220', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7221', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7222', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7223', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7224', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7225', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7226', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7227', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7228', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7229', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7230', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7231', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7232', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7233', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7234', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a7235', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7236', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7237', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7238', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7239', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a7240', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7241', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7242', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7243', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7244', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a7245', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7246', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7247', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7248', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7249', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7250', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7251', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7252', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7253', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7254', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7255', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7256', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7257', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7258', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a7259', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7260', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7261', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7262', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7263', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7264', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7265', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7266', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7267', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7268', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7269', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7270', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7271', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7272', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7273', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7274', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7275', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7276', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7277', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7278', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7279', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0', 'Padua-Rome-0')), ('a7280', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7281', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7282', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7283', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7284', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7285', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7286', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7287', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7288', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7289', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7290', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7291', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7292', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7293', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7294', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7295', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7296', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7297', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7298', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7299', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7300', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7301', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-7', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7302', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7303', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7304', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7305', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7306', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7307', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7308', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7309', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7310', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7311', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7312', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7313', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7314', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7315', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7316', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7317', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7318', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7319', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7320', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7321', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7322', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7323', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7324', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7325', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7326', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7327', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7328', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7329', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7330', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7331', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7332', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-3')), ('a7333', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7334', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7335', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7336', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7337', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7338', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7339', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7340', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7341', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7342', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7343', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7344', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7345', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7346', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7347', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7348', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7349', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7350', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7351', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7352', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7353', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7354', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7355', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7356', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7357', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7358', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7359', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7360', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7361', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7362', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7363', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7364', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7365', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7366', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7367', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7368', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7369', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7370', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7371', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7372', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7373', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7374', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7375', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7376', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7377', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7378', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7379', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7380', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7381', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7382', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a7383', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7384', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7385', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7386', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7387', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7388', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7389', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7390', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7391', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7392', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7393', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7394', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7395', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Padua-0')), ('a7396', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7397', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7398', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7399', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7400', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7401', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7402', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7403', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7404', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7405', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7406', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7407', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a7408', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7409', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7410', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7411', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7412', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a7413', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7414', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7415', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7416', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7417', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7418', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7419', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7420', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7421', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7422', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7423', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7424', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7425', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7426', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7427', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7428', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7429', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7430', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7431', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7432', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7433', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7434', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7435', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7436', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7437', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7438', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7439', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7440', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7441', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7442', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7443', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7444', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-3')), ('a7445', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7446', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7447', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a7448', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7449', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7450', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7451', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7452', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7453', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7454', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7455', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7456', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7457', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7458', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7459', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7460', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7461', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7462', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7463', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7464', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7465', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7466', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7467', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7468', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7469', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7470', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7471', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7472', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7473', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7474', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7475', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7476', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7477', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7478', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7479', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7480', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7481', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7482', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7483', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7484', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a7485', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7486', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7487', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7488', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7489', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7490', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7491', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7492', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7493', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7494', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7495', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a7496', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7497', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7498', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7499', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7500', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7501', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7502', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7503', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7504', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7505', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7506', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7507', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7508', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7509', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7510', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7511', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7512', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7513', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7514', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7515', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7516', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7517', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7518', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7519', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7520', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7521', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7522', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7523', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7524', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7525', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7526', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7527', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7528', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7529', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7530', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7531', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7532', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7533', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7534', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7535', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7536', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7537', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a7538', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7539', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7540', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7541', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7542', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7543', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7544', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7545', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7546', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7547', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7548', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7549', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7550', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7551', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7552', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7553', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Padua-0')), ('a7554', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a7555', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7556', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7557', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7558', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7559', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7560', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7561', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7562', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7563', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7564', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7565', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7566', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7567', 'E', 's2', ('Napoli-Padua-0', 'Padua-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7568', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7569', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7570', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7571', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7572', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7573', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7574', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7575', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7576', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a7577', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7578', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7579', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7580', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7581', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7582', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7583', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7584', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7585', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7586', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7587', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7588', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7589', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7590', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7591', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7592', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7593', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-7', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7594', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7595', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7596', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a7597', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7598', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7599', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7600', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7601', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7602', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7603', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7604', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7605', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7606', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7607', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7608', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7609', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7610', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7611', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7612', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7613', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7614', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7615', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7616', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a7617', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7618', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7619', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7620', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7621', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7622', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7623', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7624', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-7', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7625', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7626', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7627', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7628', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7629', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7630', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7631', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7632', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7633', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7634', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7635', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7636', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7637', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7638', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7639', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7640', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7641', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7642', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7643', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7644', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7645', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7646', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7647', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7648', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7649', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7650', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7651', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7652', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7653', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7654', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7655', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7656', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7657', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7658', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7659', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7660', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7661', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7662', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7663', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7664', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7665', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7666', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7667', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7668', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7669', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7670', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7671', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7672', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7673', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7674', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7675', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7676', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7677', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7678', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7679', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7680', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7681', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7682', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7683', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7684', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7685', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7686', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7687', 'F', 's2', ('Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7688', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7689', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7690', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7691', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7692', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a7693', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7694', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a7695', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7696', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7697', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7698', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a7699', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7700', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7701', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7702', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7703', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7704', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7705', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7706', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7707', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7708', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7709', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7710', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a7711', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7712', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7713', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7714', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7715', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7716', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7717', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7718', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7719', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7720', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a7721', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7722', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7723', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7724', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7725', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7726', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7727', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7728', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7729', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7730', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7731', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7732', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7733', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7734', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7735', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7736', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7737', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7738', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7739', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7740', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7741', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7742', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7743', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7744', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7745', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7746', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7747', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7748', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7749', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7750', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7751', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7752', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7753', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7754', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7755', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a7756', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7757', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7758', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7759', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7760', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7761', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7762', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7763', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7764', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7765', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7766', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7767', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7768', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7769', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7770', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7771', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7772', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7773', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7774', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7775', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7776', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7777', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7778', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7779', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7780', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7781', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7782', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7783', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7784', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7785', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7786', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7787', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7788', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7789', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7790', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7791', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7792', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7793', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7794', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7795', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7796', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7797', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7798', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7799', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7800', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7801', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7802', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7803', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7804', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7805', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7806', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7807', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7808', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7809', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7810', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7811', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7812', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7813', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7814', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7815', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7816', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7817', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7818', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7819', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7820', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7821', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7822', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7823', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7824', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7825', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7826', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7827', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7828', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7829', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7830', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7831', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7832', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a7833', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7834', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7835', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7836', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7837', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7838', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7839', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7840', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7841', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7842', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7843', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7844', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7845', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7846', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7847', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7848', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7849', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7850', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7851', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7852', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7853', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7854', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7855', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7856', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7857', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7858', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7859', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7860', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7861', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7862', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7863', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7864', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7865', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7866', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7867', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7868', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0', 'Verona-Padua-0')), ('a7869', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7870', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7871', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7872', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7873', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7874', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7875', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7876', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7877', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7878', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7879', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7880', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0', 'Padua-Rome-0')), ('a7881', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7882', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7883', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7884', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7885', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7886', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7887', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7888', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7889', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7890', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7891', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a7892', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7893', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7894', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7895', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7896', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7897', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7898', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7899', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7900', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7901', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7902', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a7903', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7904', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7905', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7906', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7907', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7908', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7909', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7910', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7911', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Padua-0', 'Padua-Rome-0')), ('a7912', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7913', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a7914', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a7915', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a7916', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a7917', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7918', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7919', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7920', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7921', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7922', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7923', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7924', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7925', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7926', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7927', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7928', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7929', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7930', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7931', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7932', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7933', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7934', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7935', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7936', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7937', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7938', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7939', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7940', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7941', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a7942', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7943', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7944', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7945', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7946', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7947', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7948', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7949', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a7950', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7951', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7952', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7953', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7954', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7955', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7956', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7957', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7958', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7959', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7960', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7961', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7962', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7963', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7964', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7965', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a7966', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7967', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7968', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7969', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a7970', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7971', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a7972', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7973', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7974', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7975', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7976', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7977', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7978', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7979', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7980', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7981', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a7982', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a7983', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7984', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a7985', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7986', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7987', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a7988', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a7989', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a7990', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7991', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a7992', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7993', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7994', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7995', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7996', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7997', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7998', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a7999', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8000', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8001', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8002', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8003', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8004', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8005', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a8006', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Rome-0')), ('a8007', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8008', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8009', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8010', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8011', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8012', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8013', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8014', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8015', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0', 'Verona-Padua-0')), ('a8016', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8017', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8018', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8019', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8020', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8021', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a8022', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8023', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8024', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8025', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8026', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8027', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8028', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8029', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8030', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8031', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8032', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8033', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8034', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8035', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8036', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8037', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8038', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8039', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8040', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8041', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8042', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8043', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8044', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8045', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8046', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8047', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8048', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8049', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8050', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a8051', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8052', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8053', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8054', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8055', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8056', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8057', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8058', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8059', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8060', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8061', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8062', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8063', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8064', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8065', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8066', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8067', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8068', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8069', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8070', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8071', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8072', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8073', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8074', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8075', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8076', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8077', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8078', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8079', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8080', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8081', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8082', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8083', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8084', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8085', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8086', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8087', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8088', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8089', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8090', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8091', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8092', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8093', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8094', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8095', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8096', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8097', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8098', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8099', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8100', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8101', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8102', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8103', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8104', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8105', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8106', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a8107', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8108', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8109', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8110', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8111', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8112', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8113', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8114', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8115', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8116', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8117', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8118', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8119', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8120', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8121', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8122', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8123', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8124', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8125', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8126', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8127', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8128', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8129', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8130', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8131', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8132', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8133', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8134', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8135', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8136', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8137', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8138', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8139', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8140', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8141', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8142', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8143', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8144', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8145', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8146', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8147', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8148', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8149', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a8150', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8151', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8152', 'F', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8153', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8154', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8155', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8156', 'F', 's2', ('Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8157', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8158', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8159', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8160', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8161', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8162', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8163', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8164', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8165', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8166', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8167', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8168', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8169', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8170', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8171', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8172', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a8173', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8174', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8175', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8176', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8177', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8178', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8179', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8180', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8181', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8182', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8183', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8184', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8185', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8186', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8187', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8188', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8189', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8190', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8191', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8192', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8193', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8194', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8195', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8196', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8197', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8198', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8199', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8200', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8201', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8202', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8203', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8204', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8205', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8206', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8207', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8208', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8209', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8210', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8211', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8212', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8213', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8214', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8215', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8216', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8217', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a8218', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8219', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8220', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8221', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8222', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8223', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8224', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8225', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8226', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8227', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8228', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8229', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8230', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8231', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8232', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8233', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8234', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8235', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a8236', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8237', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8238', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8239', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8240', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8241', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8242', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a8243', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8244', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8245', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8246', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8247', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8248', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8249', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8250', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8251', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-2')), ('a8252', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8253', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8254', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8255', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8256', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8257', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8258', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8259', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0', 'Rome-Padua-0')), ('a8260', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8261', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8262', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8263', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8264', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8265', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8266', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8267', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8268', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8269', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8270', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8271', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8272', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8273', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a8274', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8275', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8276', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8277', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8278', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8279', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8280', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8281', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8282', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8283', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8284', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a8285', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8286', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8287', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8288', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8289', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8290', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8291', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8292', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8293', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8294', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8295', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8296', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8297', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8298', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8299', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8300', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8301', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8302', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8303', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8304', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8305', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8306', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8307', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8308', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8309', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8310', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8311', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8312', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8313', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8314', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8315', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8316', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8317', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a8318', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8319', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8320', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8321', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8322', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8323', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8324', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8325', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8326', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8327', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8328', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8329', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8330', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8331', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8332', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8333', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8334', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8335', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a8336', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8337', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8338', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8339', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8340', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8341', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8342', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8343', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8344', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a8345', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8346', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8347', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8348', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8349', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8350', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8351', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8352', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8353', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8354', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8355', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8356', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8357', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a8358', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8359', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8360', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8361', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8362', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a8363', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8364', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8365', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8366', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8367', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8368', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8369', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8370', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8371', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8372', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8373', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8374', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8375', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8376', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8377', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8378', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8379', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8380', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8381', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8382', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8383', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8384', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8385', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8386', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8387', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8388', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8389', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8390', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8391', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8392', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8393', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8394', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8395', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8396', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8397', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8398', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8399', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8400', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8401', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8402', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8403', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8404', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8405', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8406', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8407', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8408', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8409', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8410', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8411', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8412', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8413', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8414', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8415', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a8416', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8417', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8418', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8419', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8420', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8421', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8422', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8423', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8424', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8425', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8426', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8427', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8428', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8429', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8430', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8431', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8432', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8433', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8434', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8435', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8436', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8437', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8438', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8439', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8440', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8441', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a8442', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8443', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8444', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8445', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8446', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8447', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8448', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8449', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8450', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8451', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8452', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8453', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Padua-0', 'Padua-Verona-0')), ('a8454', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8455', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a8456', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8457', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8458', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8459', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8460', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8461', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8462', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8463', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8464', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8465', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8466', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8467', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8468', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8469', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8470', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8471', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8472', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8473', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Padua-0')), ('a8474', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8475', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8476', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8477', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8478', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8479', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8480', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8481', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8482', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8483', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8484', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8485', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8486', 'F', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8487', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8488', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8489', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8490', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8491', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8492', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8493', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8494', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8495', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8496', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8497', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8498', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8499', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8500', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8501', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8502', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8503', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a8504', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8505', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8506', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8507', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8508', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8509', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8510', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8511', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8512', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8513', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8514', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8515', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8516', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8517', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8518', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8519', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8520', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8521', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8522', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8523', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8524', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8525', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8526', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8527', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8528', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8529', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8530', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8531', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a8532', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8533', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8534', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8535', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8536', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8537', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8538', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8539', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8540', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8541', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8542', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8543', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8544', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8545', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8546', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8547', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8548', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8549', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8550', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8551', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8552', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8553', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8554', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8555', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8556', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8557', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8558', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8559', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8560', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8561', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8562', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a8563', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8564', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8565', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8566', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8567', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8568', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8569', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8570', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-2')), ('a8571', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8572', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8573', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8574', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8575', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8576', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8577', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8578', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8579', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8580', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8581', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8582', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8583', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8584', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8585', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a8586', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8587', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8588', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8589', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-4')), ('a8590', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8591', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8592', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8593', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8594', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8595', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8596', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8597', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8598', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8599', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8600', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8601', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8602', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8603', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Rome-0')), ('a8604', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8605', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8606', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8607', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8608', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8609', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8610', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8611', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8612', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8613', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8614', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8615', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8616', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8617', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8618', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8619', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8620', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8621', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8622', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8623', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8624', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8625', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8626', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8627', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8628', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8629', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8630', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-7', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8631', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8632', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8633', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8634', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8635', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8636', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8637', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8638', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8639', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8640', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8641', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8642', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8643', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8644', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8645', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a8646', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8647', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8648', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8649', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8650', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8651', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8652', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8653', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8654', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8655', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8656', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8657', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8658', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8659', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8660', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8661', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8662', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8663', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8664', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8665', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8666', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a8667', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8668', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8669', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8670', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8671', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8672', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a8673', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8674', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8675', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8676', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8677', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8678', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8679', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a8680', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Rome-0')), ('a8681', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8682', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8683', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8684', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8685', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8686', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8687', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8688', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8689', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8690', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8691', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8692', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8693', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8694', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8695', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8696', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8697', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8698', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8699', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8700', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8701', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8702', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8703', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8704', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2', 'Verona-Rome-0')), ('a8705', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8706', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8707', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8708', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8709', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a8710', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8711', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8712', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8713', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8714', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8715', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8716', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8717', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8718', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8719', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8720', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8721', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8722', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8723', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8724', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8725', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8726', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a8727', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8728', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8729', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8730', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8731', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8732', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8733', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8734', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8735', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8736', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8737', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8738', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8739', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8740', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8741', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8742', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8743', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8744', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8745', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8746', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8747', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8748', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8749', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8750', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8751', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8752', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8753', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8754', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8755', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8756', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8757', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8758', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8759', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8760', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8761', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8762', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8763', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8764', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8765', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8766', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8767', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8768', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8769', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8770', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8771', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a8772', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8773', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8774', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8775', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8776', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8777', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8778', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8779', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8780', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8781', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8782', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8783', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a8784', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8785', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8786', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8787', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8788', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8789', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8790', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8791', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8792', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8793', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8794', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8795', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8796', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8797', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8798', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8799', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8800', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8801', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8802', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8803', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a8804', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8805', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8806', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8807', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8808', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8809', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8810', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8811', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8812', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8813', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8814', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8815', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8816', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8817', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8818', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8819', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8820', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8821', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8822', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8823', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8824', 'F', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8825', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8826', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8827', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8828', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8829', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8830', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a8831', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8832', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8833', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8834', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8835', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8836', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8837', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8838', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8839', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a8840', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a8841', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8842', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8843', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8844', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8845', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8846', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-2')), ('a8847', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8848', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8849', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8850', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8851', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a8852', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8853', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8854', 'F', 's2', ('Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a8855', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8856', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8857', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8858', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8859', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8860', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8861', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8862', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8863', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8864', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8865', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8866', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8867', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8868', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8869', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8870', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8871', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8872', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8873', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8874', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8875', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8876', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8877', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8878', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8879', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8880', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8881', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8882', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a8883', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8884', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8885', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8886', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8887', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8888', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8889', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a8890', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8891', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8892', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8893', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8894', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8895', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8896', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8897', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8898', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8899', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8900', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8901', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8902', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8903', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8904', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8905', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8906', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8907', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8908', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8909', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a8910', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8911', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8912', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8913', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8914', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8915', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8916', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8917', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8918', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8919', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8920', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8921', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a8922', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8923', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8924', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8925', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8926', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8927', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8928', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8929', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8930', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8931', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-3')), ('a8932', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8933', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8934', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8935', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8936', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8937', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8938', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8939', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8940', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8941', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8942', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8943', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0', 'Padua-Rome-0')), ('a8944', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8945', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8946', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8947', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8948', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8949', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8950', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8951', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8952', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8953', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a8954', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8955', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8956', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8957', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8958', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a8959', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8960', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a8961', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8962', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8963', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8964', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8965', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8966', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Padua-0')), ('a8967', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8968', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8969', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8970', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8971', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8972', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8973', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a8974', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8975', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a8976', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8977', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8978', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8979', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8980', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8981', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8982', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8983', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8984', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8985', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a8986', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a8987', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8988', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a8989', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8990', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Padua-0')), ('a8991', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a8992', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8993', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a8994', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8995', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8996', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a8997', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a8998', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a8999', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9000', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9001', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9002', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9003', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9004', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9005', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9006', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9007', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9008', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9009', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9010', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9011', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9012', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9013', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a9014', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9015', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9016', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9017', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9018', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9019', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9020', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a9021', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9022', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9023', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9024', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9025', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9026', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a9027', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9028', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9029', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0', 'Verona-Padua-0')), ('a9030', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9031', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9032', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9033', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9034', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9035', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9036', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9037', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a9038', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9039', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9040', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9041', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9042', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9043', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a9044', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9045', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9046', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9047', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9048', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9049', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9050', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a9051', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a9052', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9053', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9054', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9055', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9056', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9057', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9058', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9059', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9060', 'E', 's2', ('Napoli-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Rome-0')), ('a9061', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a9062', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9063', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9064', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9065', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9066', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9067', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9068', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a9069', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9070', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9071', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9072', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9073', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9074', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9075', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9076', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9077', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9078', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9079', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9080', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9081', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9082', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9083', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9084', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9085', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9086', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9087', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9088', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9089', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9090', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9091', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-6', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9092', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9093', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9094', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9095', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9096', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9097', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9098', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9099', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9100', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9101', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9102', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9103', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9104', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a9105', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9106', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9107', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9108', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9109', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9110', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9111', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9112', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9113', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9114', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9115', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9116', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9117', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9118', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9119', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9120', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9121', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9122', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9123', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9124', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9125', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9126', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9127', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9128', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9129', 'E', 's2', ('Padua-Rome-0', 'Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9130', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9131', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9132', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9133', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9134', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9135', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9136', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9137', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9138', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9139', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9140', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9141', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9142', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9143', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9144', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a9145', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9146', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9147', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9148', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9149', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9150', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a9151', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9152', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9153', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9154', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9155', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9156', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9157', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9158', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9159', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9160', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9161', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9162', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9163', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9164', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9165', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9166', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9167', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9168', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9169', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9170', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9171', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a9172', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9173', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9174', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9175', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9176', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9177', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9178', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9179', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9180', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9181', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9182', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9183', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9184', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9185', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9186', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9187', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9188', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9189', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9190', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9191', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9192', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9193', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9194', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9195', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9196', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9197', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9198', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9199', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9200', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9201', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9202', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9203', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9204', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9205', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9206', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9207', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9208', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9209', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9210', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9211', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9212', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9213', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9214', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9215', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9216', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9217', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9218', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9219', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9220', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9221', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9222', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9223', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9224', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9225', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9226', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9227', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9228', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9229', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9230', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-2')), ('a9231', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9232', 'E', 's2', ('Padua-Rome-0', 'Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9233', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9234', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9235', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9236', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9237', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9238', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9239', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9240', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a9241', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9242', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9243', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a9244', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9245', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9246', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9247', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9248', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0', 'Verona-Padua-0')), ('a9249', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9250', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9251', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9252', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9253', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9254', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9255', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9256', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9257', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9258', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9259', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a9260', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9261', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9262', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-2')), ('a9263', 'A', 's2', ('Napoli-Udine-3', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9264', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9265', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9266', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9267', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9268', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-5')), ('a9269', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9270', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9271', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9272', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9273', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9274', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9275', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9276', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9277', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9278', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9279', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9280', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9281', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9282', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9283', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9284', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9285', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9286', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9287', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9288', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9289', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9290', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9291', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9292', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a9293', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9294', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9295', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9296', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9297', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9298', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9299', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9300', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9301', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9302', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9303', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9304', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9305', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9306', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a9307', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9308', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9309', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9310', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9311', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9312', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9313', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9314', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9315', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9316', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9317', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9318', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9319', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9320', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9321', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9322', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9323', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9324', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9325', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9326', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9327', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9328', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9329', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9330', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a9331', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9332', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9333', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9334', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9335', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9336', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9337', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9338', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9339', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9340', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9341', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9342', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-2')), ('a9343', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9344', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9345', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9346', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9347', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9348', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9349', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9350', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9351', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9352', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9353', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9354', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9355', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9356', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9357', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9358', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9359', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9360', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9361', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9362', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9363', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9364', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9365', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9366', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9367', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9368', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9369', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9370', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9371', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a9372', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9373', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9374', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9375', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9376', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9377', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9378', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9379', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9380', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9381', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9382', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9383', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9384', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9385', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9386', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9387', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9388', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9389', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9390', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a9391', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9392', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9393', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9394', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9395', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9396', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9397', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a9398', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9399', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9400', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9401', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9402', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9403', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9404', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9405', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9406', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9407', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9408', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9409', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9410', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9411', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9412', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9413', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-3')), ('a9414', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9415', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9416', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9417', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9418', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9419', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9420', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9421', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9422', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9423', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9424', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9425', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9426', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9427', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9428', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a9429', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9430', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9431', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9432', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9433', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9434', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9435', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9436', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9437', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9438', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9439', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5', 'Verona-Rome-0')), ('a9440', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9441', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9442', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9443', 'G', 's2', ('Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9444', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9445', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9446', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9447', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9448', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9449', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9450', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9451', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9452', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9453', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9454', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9455', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9456', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9457', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9458', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9459', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9460', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9461', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9462', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9463', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9464', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9465', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9466', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9467', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9468', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9469', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9470', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9471', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9472', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9473', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9474', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9475', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9476', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9477', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-3', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9478', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9479', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9480', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9481', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9482', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9483', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9484', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9485', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9486', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0')), ('a9487', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9488', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9489', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9490', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9491', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9492', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9493', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9494', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9495', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9496', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9497', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9498', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9499', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9500', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9501', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9502', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9503', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9504', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-8', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9505', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9506', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9507', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9508', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9509', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9510', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9511', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9512', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9513', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9514', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9515', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9516', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9517', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9518', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9519', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9520', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9521', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9522', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9523', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9524', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9525', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a9526', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9527', 'C', 's2', ('Napoli-Trento-0', 'Trento-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9528', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9529', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9530', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9531', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9532', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9533', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9534', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9535', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a9536', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9537', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9538', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9539', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9540', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9541', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9542', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9543', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9544', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9545', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9546', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9547', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9548', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9549', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9550', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9551', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9552', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9553', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9554', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9555', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9556', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9557', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9558', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9559', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9560', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9561', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9562', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9563', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9564', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9565', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9566', 'E', 's2', ('Napoli-Padua-0', 'Padua-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9567', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9568', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9569', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9570', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9571', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9572', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9573', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9574', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9575', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9576', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9577', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9578', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9579', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9580', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9581', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9582', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9583', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a9584', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9585', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9586', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9587', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9588', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9589', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9590', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Rome-0', 'Rome-Verona-0')), ('a9591', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9592', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9593', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9594', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a9595', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9596', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9597', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9598', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9599', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9600', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9601', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9602', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9603', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9604', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9605', 'E', 's2', ('Napoli-Udine-2', 'Udine-Padua-0', 'Padua-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9606', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9607', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9608', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9609', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9610', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9611', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9612', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9613', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9614', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9615', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9616', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9617', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9618', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9619', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9620', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9621', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9622', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9623', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9624', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9625', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9626', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a9627', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a9628', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9629', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9630', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9631', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9632', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9633', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9634', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9635', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9636', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9637', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9638', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a9639', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9640', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9641', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9642', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9643', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9644', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9645', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9646', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9647', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9648', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9649', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9650', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9651', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9652', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9653', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9654', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9655', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9656', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9657', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9658', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9659', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9660', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9661', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9662', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9663', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9664', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9665', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9666', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a9667', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9668', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9669', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9670', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9671', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9672', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9673', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9674', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-2')), ('a9675', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9676', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9677', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9678', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9679', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9680', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9681', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9682', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9683', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9684', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Padua-0', 'Padua-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9685', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9686', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9687', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9688', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9689', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9690', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9691', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Padua-0', 'Padua-Verona-0', 'Verona-Rome-0')), ('a9692', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9693', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9694', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9695', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9696', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9697', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9698', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9699', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9700', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9701', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9702', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9703', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9704', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Rome-0', 'Rome-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9705', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9706', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9707', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9708', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9709', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9710', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9711', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9712', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9713', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a9714', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9715', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9716', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9717', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9718', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9719', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9720', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9721', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9722', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9723', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9724', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9725', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9726', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9727', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9728', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9729', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9730', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9731', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9732', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9733', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9734', 'A', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9735', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9736', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9737', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9738', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9739', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9740', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9741', 'G', 's2', ('Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9742', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9743', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9744', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9745', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9746', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9747', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9748', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9749', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9750', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9751', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-0')), ('a9752', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9753', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9754', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-5')), ('a9755', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9756', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9757', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9758', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9759', 'C', 's2', ('Trento-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9760', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9761', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9762', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9763', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9764', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9765', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9766', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9767', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9768', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9769', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Padua-0', 'Padua-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9770', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9771', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9772', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9773', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9774', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9775', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a9776', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9777', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9778', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9779', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a9780', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9781', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9782', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9783', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9784', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9785', 'G', 's2', ('Napoli-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9786', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9787', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9788', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9789', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9790', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9791', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-5')), ('a9792', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9793', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9794', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9795', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9796', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9797', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9798', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9799', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9800', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9801', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9802', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0', 'Verona-Padua-0')), ('a9803', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9804', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9805', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9806', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9807', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9808', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9809', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9810', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9811', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9812', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9813', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9814', 'A', 's2', ('Napoli-Udine-2', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9815', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9816', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9817', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9818', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9819', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9820', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9821', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9822', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9823', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9824', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9825', 'E', 's2', ('Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9826', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9827', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9828', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-3')), ('a9829', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a9830', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9831', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9832', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9833', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9834', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9835', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a9836', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9837', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9838', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9839', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9840', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9841', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9842', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9843', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9844', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9845', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9846', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9847', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9848', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9849', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9850', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9851', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Trento-0', 'Trento-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9852', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9853', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Rome-0', 'Rome-Verona-0')), ('a9854', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9855', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9856', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9857', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9858', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9859', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9860', 'F', 's2', ('Napoli-Udine-0', 'Udine-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9861', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9862', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9863', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9864', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9865', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9866', 'E', 's2', ('Napoli-Rome-0', 'Rome-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-5')), ('a9867', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9868', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9869', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Trento-0')), ('a9870', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9871', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a9872', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9873', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9874', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Trento-0', 'Trento-Verona-0')), ('a9875', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9876', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a9877', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9878', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9879', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9880', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9881', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9882', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9883', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9884', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9885', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9886', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9887', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9888', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9889', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9890', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9891', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a9892', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9893', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9894', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9895', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9896', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9897', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9898', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9899', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9900', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9901', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9902', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9903', 'A', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9904', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9905', 'G', 's2', ('Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9906', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9907', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9908', 'A', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9909', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9910', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9911', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9912', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9913', 'G', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9914', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Padua-0', 'Padua-Bologna-0', 'Bologna-Verona-0')), ('a9915', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9916', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3', 'Verona-Trento-0')), ('a9917', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9918', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9919', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9920', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9921', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9922', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9923', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9924', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2')), ('a9925', 'E', 's2', ('Napoli-Udine-3', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9926', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9927', 'H', 's2', ('Napoli-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9928', 'E', 's2', ('Rome-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9929', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9930', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9931', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9932', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9933', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9934', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9935', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9936', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9937', 'J', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9938', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9939', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9940', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Trento-0', 'Trento-Bologna-0', 'Bologna-Verona-0')), ('a9941', 'G', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9942', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-5')), ('a9943', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9944', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9945', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9946', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9947', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9948', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9949', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9950', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-4')), ('a9951', 'E', 's2', ('Padua-Napoli-0', 'Napoli-Udine-0', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9952', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9953', 'A', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9954', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-6', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9955', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9956', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9957', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9958', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9959', 'G', 's2', ('Napoli-Udine-0', 'Udine-Firenze-5', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9960', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9961', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9962', 'F', 's2', ('Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9963', 'E', 's2', ('Napoli-Udine-2', 'Udine-Rome-0', 'Rome-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a9964', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9965', 'H', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9966', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9967', 'E', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Padua-0')), ('a9968', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9969', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-2', 'Genova-Firenze-2', 'Firenze-Bologna-2', 'Bologna-Verona-0')), ('a9970', 'F', 's2', ('Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9971', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9972', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Bologna-0', 'Bologna-Verona-0')), ('a9973', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')), ('a9974', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9975', 'F', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0')), ('a9976', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-5', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9977', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9978', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9979', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9980', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Rome-0', 'Rome-Bologna-0', 'Bologna-Verona-3')), ('a9981', 'A', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9982', 'E', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0', 'Verona-Rome-0')), ('a9983', 'D', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9984', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-2')), ('a9985', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9986', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-3', 'Firenze-Bologna-1', 'Bologna-Verona-0')), ('a9987', 'C', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9988', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-4', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9989', 'J', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-0', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9990', 'B', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9991', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-3', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9992', 'D', 's2', ('Napoli-Udine-2', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9993', 'I', 's2', ('Napoli-Udine-1', 'Udine-Genova-1', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9994', 'F', 's2', ('Napoli-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-0')), ('a9995', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Bologna-1', 'Bologna-Verona-1')), ('a9996', 'C', 's2', ('Napoli-Udine-0', 'Udine-Trento-0', 'Trento-Genova-1', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-3')), ('a9997', 'I', 's2', ('Napoli-Udine-0', 'Udine-Genova-7', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9998', 'B', 's2', ('Napoli-Udine-1', 'Udine-Genova-0', 'Genova-Firenze-3', 'Firenze-Bologna-0', 'Bologna-Verona-1')), ('a9999', 'G', 's2', ('Napoli-Udine-0', 'Udine-Genova-8', 'Genova-Firenze-2', 'Firenze-Bologna-0', 'Bologna-Verona-4')), ('a10000', 'A', 's2', ('Napoli-Udine-0', 'Udine-Genova-0', 'Genova-Firenze-2', 'Firenze-Verona-0')))

# %%
#count de frequency of all the singletons
freq={}
for x in dataset:
    for i in x[3]:
        if i not in freq:
            freq[i] = 1
        else:
            freq[i] = freq[i] +1
freq
# Out:
# {'Trento-Napoli-0': 110,
#  'Napoli-Milan-0': 55,
#  'Napoli-Venezia-0': 55,
#  'Rome-Milan-0': 188,
#  'Milan-Bergamo-0': 250,
#  'Bergamo-Venezia-0': 250,
#  'Bolzano-Milan-0': 250,
#  'Milan-Verona-0': 250,
#  'Verona-Venezia-0': 250,
#  'Rome-Milan-1': 62}

# %%
#remove the singletons not frequent enough, depending on a certain thresehold. 
#In this case, I've chosen 100. 
#The function outputs a tuple with the frequent items and not frequently enough items.
def prune(X,thresehold):
    reduce=[]
    for i in X:
        if X[i]<thresehold:
            reduce.append(((i,),X[i]))
    for i in reduce:
        X.pop(i[0][0])
    return (X,reduce)

# %%
S = prune(freq,100)
S
# Out:
# ({'Trento-Napoli-0': 110,
#   'Rome-Milan-0': 188,
#   'Milan-Bergamo-0': 250,
#   'Bergamo-Venezia-0': 250,
#   'Bolzano-Milan-0': 250,
#   'Milan-Verona-0': 250,
#   'Verona-Venezia-0': 250},
#  [(('Napoli-Milan-0',), 55),
#   (('Napoli-Venezia-0',), 55),
#   (('Rome-Milan-1',), 62)])

# %%
#A function that, given two trips, outputs wether they could be chained or not,
#for example, if the first trip ends in Milano, it tells you wether the second one
#starts in Milano too. In this way, we only create "possible couples" with the next function.
def match(x,y):
    w1=x
    l1=len(w1)
    w1=w1[:l1-2]
    index1=w1.index('-')
    w1=w1[index1+1:]
    
    w2=y
    l2=len(w2)
    w2=w2[:l2-2]
    index2=w2.index('-')
    w2=w2[:index2]
    
    return w1==w2

# %%
#using the above function we create couples.It also gives us a list 
#of the singletons that we could not extend, and a list of the ones we could.
#We need the latter in case the couples don't pass the prune in the next step;
#in that case, we would go back one step and offer the routes that created that couple.

def couples(X):
    nextcandidates=[]
    extend=[]
    for i in X:
        extend.append(((i,),X[i]))
    lista=[]
    for i in X:
        for j in X:
            if match(i,j):
                if ((i,),X[i]) in extend:
                    extend.remove(((i,),X[i]))
                if ((j,),X[j]) in extend:
                    extend.remove(((j,),X[j]))
                    
                if (i,j) not in lista:
                    lista.append((i,j))
                if ((i,),X[i]) not in nextcandidates:
                        nextcandidates.append(((i,),X[i]))
                if ((j,),X[j]) not in nextcandidates:
                        nextcandidates.append(((j,),X[j]))
    return (lista,extend,nextcandidates)

# %%
candidates = couples(S[0])
candidates
# Out:
# ([('Rome-Milan-0', 'Milan-Bergamo-0'),
#   ('Rome-Milan-0', 'Milan-Verona-0'),
#   ('Milan-Bergamo-0', 'Bergamo-Venezia-0'),
#   ('Bolzano-Milan-0', 'Milan-Bergamo-0'),
#   ('Bolzano-Milan-0', 'Milan-Verona-0'),
#   ('Milan-Verona-0', 'Verona-Venezia-0')],
#  [(('Trento-Napoli-0',), 110)],
#  [(('Rome-Milan-0',), 188),
#   (('Milan-Bergamo-0',), 250),
#   (('Milan-Verona-0',), 250),
#   (('Bergamo-Venezia-0',), 250),
#   (('Bolzano-Milan-0',), 250),
#   (('Verona-Venezia-0',), 250)])

# %%
#this function tells us wether a given sequence is a subsequence of a longer one.
#basically we are certifying if a given subroute is part of a bigger route in the dataset.

def subsequence(m,S):
    l=len(m)
    L=len(S)
    for i in range(0,L-l+1):
        if S[i:i+l]==m:
            return True
    return False

# %%
#given possible frequent tuples it creates a dictionary with the occurrences
#of such tuples as subsequences in the dataset.

def find(candidates,X):
    freq={}
    for i in candidates:
        for j in X:
            if subsequence(i,j[3]):
                if i in freq:
                    freq[i]=freq[i]+1
                else:
                    freq[i]=1
    return freq

# %%
F = find(candidates[0],dataset)
F
# Out:
# {('Rome-Milan-0', 'Milan-Bergamo-0'): 188,
#  ('Milan-Bergamo-0', 'Bergamo-Venezia-0'): 250,
#  ('Bolzano-Milan-0', 'Milan-Verona-0'): 250,
#  ('Milan-Verona-0', 'Verona-Venezia-0'): 250}

# %%
#prune again
s = prune(F,100)
s
# Out:
# ({('Rome-Milan-0', 'Milan-Bergamo-0'): 188,
#   ('Milan-Bergamo-0', 'Bergamo-Venezia-0'): 250,
#   ('Bolzano-Milan-0', 'Milan-Verona-0'): 250,
#   ('Milan-Verona-0', 'Verona-Venezia-0'): 250},
#  [])

# %%
#this function takes a list of tuples of the same length and combines them
#to create new tuples of length + 1. Furthermore, it only creates "logical"
#tuples. That is, it won't combine (1,2,3) with (1,2,5) but it will combine 
#(1,2,3) with (2,3,4) to create (1,2,3,4). It also gives as a list of tuples
#we could not extend, and the ones we could, for analogous reasons as in the 
#case of the function couples.

def combine(X):
    extend=[]
    for i in X:
        extend.append((i,X[i]))
    nextcandidates=[]
    lista=[]
    if len(X)!=0:
        for i in X:
            l=len(i)
            break
        for tuple1 in X:
            for tuple2 in X:
                if tuple2[:l-1] == tuple1[1:]:
                    newtuple=tuple1 + (tuple2[l-1],)
                    if (tuple1,X[tuple1]) in extend:
                        extend.remove((tuple1,X[tuple1]))
                    if (tuple2,X[tuple2]) in extend:
                        extend.remove((tuple2,X[tuple2]))
                    if newtuple not in lista:
                        lista.append(newtuple)
                    if (tuple1,X[tuple1]) not in nextcandidates:
                        nextcandidates.append((tuple1,X[tuple1]))
                    if (tuple2,X[tuple2]) not in nextcandidates:
                        nextcandidates.append((tuple2,X[tuple2]))
    return (lista,extend,nextcandidates)

# %%
(candidates,extend,nextcandidates) = combine(s[0])
(candidates,extend,nextcandidates)
# Out:
# ([('Rome-Milan-0', 'Milan-Bergamo-0', 'Bergamo-Venezia-0'),
#   ('Bolzano-Milan-0', 'Milan-Verona-0', 'Verona-Venezia-0')],
#  [],
#  [(('Rome-Milan-0', 'Milan-Bergamo-0'), 188),
#   (('Milan-Bergamo-0', 'Bergamo-Venezia-0'), 250),
#   (('Bolzano-Milan-0', 'Milan-Verona-0'), 250),
#   (('Milan-Verona-0', 'Verona-Venezia-0'), 250)])

# %%
#repeat the process
G = find(candidates,dataset)
G
# Out:
# {('Rome-Milan-0', 'Milan-Bergamo-0', 'Bergamo-Venezia-0'): 188,
#  ('Bolzano-Milan-0', 'Milan-Verona-0', 'Verona-Venezia-0'): 250}

# %%
s=prune(G,100)
s
# Out:
# ({('Rome-Milan-0', 'Milan-Bergamo-0', 'Bergamo-Venezia-0'): 188,
#   ('Bolzano-Milan-0', 'Milan-Verona-0', 'Verona-Venezia-0'): 250},
#  [])

# %%
(candidates,extend,nextcandidates) = combine(s[0])
(candidates,extend,nextcandidates)
# Out:
# ([],
#  [(('Rome-Milan-0', 'Milan-Bergamo-0', 'Bergamo-Venezia-0'), 188),
#   (('Bolzano-Milan-0', 'Milan-Verona-0', 'Verona-Venezia-0'), 250)],
#  [])

# %%
#STOP

# %%
def FREQUENT_ITEMS(dataset,thresehold):
    OFFER=[]
    
    freq={}
    for x in dataset:
        for i in x[3]:
            if i not in freq:
                freq[i] = 1
            else:
                freq[i] = freq[i] +1
    

    S = prune(freq,thresehold)[0]
    (candidates,extend,nextcandidates)=couples(S)
    OFFER=OFFER + extend
    
    
    while len(candidates)!=0:
        new=find(candidates,dataset)
        (S,H) = prune(new,thresehold)
        count=0
        for j in nextcandidates:
            for i in H:
                if subsequence(j[0],i[0]):
                    OFFER=OFFER + [j]
                    count=count+1
            if count==0:
                for i in S:
                    if subsequence(j[0],i):
                        count=count+1
            if count==0:
                OFFER=OFFER + [j]
                
        (candidates,extend,nextcandidates)=combine(S)
        OFFER = OFFER+ extend
    return OFFER

# %%
FREQUENT_ITEMS(dataset,300)
# Out:
# [(('Modena-Bergamo-0', 'Bergamo-Palermo-2'), 370),
#  (('Modena-Bergamo-0', 'Bergamo-Palermo-0', 'Palermo-Trento-0'), 1306),
#  (('Genova-Firenze-1', 'Firenze-Bologna-0', 'Bologna-Verona-2'), 411),
#  (('Napoli-Udine-0',
#    'Udine-Genova-0',
#    'Genova-Firenze-2',
#    'Firenze-Bologna-0',
#    'Bologna-Verona-0'),
#   576)]
